# %% [markdown]
# # P7_Scoring_00_Martinez_Nicolas_Modelisation

# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Loading" data-toc-modified-id="Loading-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Loading</a></span><ul class="toc-item"><li><span><a href="#Modules" data-toc-modified-id="Modules-1.1"><span class="toc-item-num">1.1&nbsp;&nbsp;</span>Modules</a></span></li><li><span><a href="#Data" data-toc-modified-id="Data-1.2"><span class="toc-item-num">1.2&nbsp;&nbsp;</span>Data</a></span></li></ul></li><li><span><a href="#Models" data-toc-modified-id="Models-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Models</a></span><ul class="toc-item"><li><span><a href="#Make-score" data-toc-modified-id="Make-score-2.1"><span class="toc-item-num">2.1&nbsp;&nbsp;</span>Make score</a></span></li><li><span><a href="#Using-application_train" data-toc-modified-id="Using-application_train-2.2"><span class="toc-item-num">2.2&nbsp;&nbsp;</span>Using application_train</a></span><ul class="toc-item"><li><span><a href="#Oversampling-/-Undersampling" data-toc-modified-id="Oversampling-/-Undersampling-2.2.1"><span class="toc-item-num">2.2.1&nbsp;&nbsp;</span>Oversampling / Undersampling</a></span></li><li><span><a href="#Training" data-toc-modified-id="Training-2.2.2"><span class="toc-item-num">2.2.2&nbsp;&nbsp;</span>Training</a></span></li></ul></li><li><span><a href="#Using-data" data-toc-modified-id="Using-data-2.3"><span class="toc-item-num">2.3&nbsp;&nbsp;</span>Using data</a></span><ul class="toc-item"><li><span><a href="#Oversampling-/-Undersampling" data-toc-modified-id="Oversampling-/-Undersampling-2.3.1"><span class="toc-item-num">2.3.1&nbsp;&nbsp;</span>Oversampling / Undersampling</a></span></li><li><span><a href="#Training" data-toc-modified-id="Training-2.3.2"><span class="toc-item-num">2.3.2&nbsp;&nbsp;</span>Training</a></span></li></ul></li><li><span><a href="#Optimisation" data-toc-modified-id="Optimisation-2.4"><span class="toc-item-num">2.4&nbsp;&nbsp;</span>Optimisation</a></span><ul class="toc-item"><li><span><a href="#Test-App_train-VS-Data2" data-toc-modified-id="Test-App_train-VS-Data2-2.4.1"><span class="toc-item-num">2.4.1&nbsp;&nbsp;</span>Test App_train VS Data2</a></span></li><li><span><a href="#Test-Scorer-Weighted_fp_score" data-toc-modified-id="Test-Scorer-Weighted_fp_score-2.4.2"><span class="toc-item-num">2.4.2&nbsp;&nbsp;</span>Test Scorer Weighted_fp_score</a></span></li><li><span><a href="#Test-RandomizedSearchCV" data-toc-modified-id="Test-RandomizedSearchCV-2.4.3"><span class="toc-item-num">2.4.3&nbsp;&nbsp;</span>Test RandomizedSearchCV</a></span></li><li><span><a href="#In-depth-Opti" data-toc-modified-id="In-depth-Opti-2.4.4"><span class="toc-item-num">2.4.4&nbsp;&nbsp;</span>In-depth Opti</a></span></li></ul></li><li><span><a href="#Feature-importance" data-toc-modified-id="Feature-importance-2.5"><span class="toc-item-num">2.5&nbsp;&nbsp;</span>Feature importance</a></span><ul class="toc-item"><li><span><a href="#Sklearn" data-toc-modified-id="Sklearn-2.5.1"><span class="toc-item-num">2.5.1&nbsp;&nbsp;</span>Sklearn</a></span></li><li><span><a href="#LGBM" data-toc-modified-id="LGBM-2.5.2"><span class="toc-item-num">2.5.2&nbsp;&nbsp;</span>LGBM</a></span></li><li><span><a href="#Shap" data-toc-modified-id="Shap-2.5.3"><span class="toc-item-num">2.5.3&nbsp;&nbsp;</span>Shap</a></span><ul class="toc-item"><li><span><a href="#KernelExplainer" data-toc-modified-id="KernelExplainer-2.5.3.1"><span class="toc-item-num">2.5.3.1&nbsp;&nbsp;</span>KernelExplainer</a></span></li><li><span><a href="#TreeExplainer" data-toc-modified-id="TreeExplainer-2.5.3.2"><span class="toc-item-num">2.5.3.2&nbsp;&nbsp;</span>TreeExplainer</a></span></li></ul></li></ul></li></ul></li><li><span><a href="#ready-to-API" data-toc-modified-id="ready-to-API-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>ready to API</a></span></li></ul></div>

# %% [markdown]
# ## Loading

# %% [markdown]
# ### Modules

# %%
import pandas as pd
pd.set_option('display.max_columns', None)
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()
import gc
import warnings
warnings.filterwarnings("ignore")
import time
import missingno as msno
from tqdm.notebook import trange, tqdm
import os
import z_nm_functions as nm
from collections import Counter
import pickle

# %%
if str(os.getcwd())[0] == "C":
    from sklearnex import patch_sklearn
    patch_sklearn()
else:
    from google.colab import drive
    drive.mount('/content/drive')
    os.chdir("drive/MyDrive/OC/7_Dashboard_en_ligne")
# Out:
# Intel(R) Extension for Scikit-learn* enabled (https://github.com/intel/scikit-learn-intelex)

# %%
from sklearn.compose import ColumnTransformer
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import LabelEncoder,StandardScaler

from imblearn.pipeline import Pipeline
from imblearn.over_sampling import SMOTE
from imblearn.under_sampling import RandomUnderSampler

from sklearn.model_selection import train_test_split, StratifiedKFold, GridSearchCV, RandomizedSearchCV
from sklearn.pipeline import make_pipeline

from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier, GradientBoostingClassifier
from sklearn.neural_network import MLPClassifier

import lightgbm as lgb
from lightgbm import LGBMClassifier

from sklearn.metrics import PrecisionRecallDisplay , plot_confusion_matrix, precision_score, recall_score , f1_score, roc_auc_score, classification_report, confusion_matrix
from sklearn.metrics import make_scorer, roc_curve, RocCurveDisplay

# %%
import shap

# %% [markdown]
# ### Data

# %%
application_train = pd.read_pickle("application_train.pickle")
data2 = pd.read_pickle("data2.pickle")

# %%
with open('model_opti.pickle', 'rb') as f:
    model_opti = pickle.load(f)

# %%
with open('trained_models.pickle', 'rb') as f:
    trained_models = pickle.load(f)

# %%
with open('trained_models2.pickle', 'rb') as f:
    trained_models2 = pickle.load(f)

# %% [markdown]
# ## Models

# %% [markdown]
# ### Make score

# %%
def false_negative(y_t,y_p):
    return -confusion_matrix(y_t,y_p).ravel()[2] / y_t.shape[0]
# Make a scorer from a performance metric or loss function.
false_negative_score = make_scorer(false_negative)

# %%
def weighted_fp(y_t, y_p, wtn=1, wfp=7, wfn=10, wtp=1):
    tn, fp, fn, tp = confusion_matrix(y_t, y_p).ravel()
    S = wtn + wfp + wfn + wtp
    return -(wtn * tn + wfp * fp + wfn * fn + wtp * tp) / S
weighted_fp_score = make_scorer(weighted_fp)

# %%
def train_model(model, X_train, y_train, X_test, y_test): 
#     pipe = Pipeline([('scaler', StandardScaler()),('clf', model["clf"])])
    start_time = time.time()
    model["clf"].fit(X_train, y_train)
    train_time = time.time() - start_time

    train_accuracy =  model["clf"].score(X_train, y_train)
    test_accuracy = model["clf"].score(X_test, y_test) 
    y_predict = model["clf"].predict(X_test)
    
    plot_confusion_matrix(model["clf"], X_test, y_test, cmap = "Blues")
    plt.show()
#     print(classification_report(y_test,y_predict))
#     PrecisionRecallDisplay.from_estimator(pipe, X_test, y_test)
#     plt.show()
#     fpr, tpr, _ = roc_curve(y_test, y_predict)
#     roc_display = RocCurveDisplay(fpr=fpr, tpr=tpr).plot()
#     plt.show()
     
    precision = precision_score(y_test,y_predict)
    recall = recall_score(y_test,y_predict)
    f1 = f1_score(y_test,y_predict)
    rocauc = roc_auc_score(y_test,y_predict)
    model_weighted_fp = weighted_fp(y_test,y_predict)
    
    model_details = {
                    "name": model["name"], 
                    "model": model["clf"],
                    "train_accuracy":train_accuracy, 
                    "test_accuracy":test_accuracy, 
                    "train_time": train_time, 
                    "precision": precision,
                    "recall": recall,
                    "f1": f1,
                    "weighted_fp": model_weighted_fp,
                    "rocauc": rocauc
                    }
    
    return model_details

# %% [markdown]
# ### Using application_train

# %%
application_train.shape
# Out:
# (307511, 87)

# %%
X = application_train.drop(['SK_ID_CURR', 'TARGET'], axis=1)
y = application_train.TARGET
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, stratify = y,  random_state=42)
SC = StandardScaler()
X_train_sc = SC.fit_transform(X_train)
X_test_sc = SC.transform(X_test)

# %% [markdown]
# #### Oversampling / Undersampling

# %%
print(Counter(y_train))
print(Counter(y_train)[0]/Counter(y_train)[1])
# Out:
# Counter({0.0: 197880, 1.0: 17377})
# 11.38746619094205

# %%
over = SMOTE(sampling_strategy=0.5)
under = RandomUnderSampler(sampling_strategy=1)

steps = [('o', over), ('u', under)]
osus = Pipeline(steps=steps)

X_train_sc, y_train = osus.fit_resample(X_train_sc, y_train)

print(Counter(y_train))
print(Counter(y_train)[0]/Counter(y_train)[1])
# Out:
# Counter({0.0: 98940, 1.0: 98940})
# 1.0

# %% [markdown]
# #### Training

# %%
trained_models = [] #  keep track of all details for models we train
models = [
          {"name": "Logistic Regression", "clf": LogisticRegression()}, 
          {"name": "Decision Tree", "clf": DecisionTreeClassifier()},
          {"name": "Random Forest", "clf": RandomForestClassifier(n_estimators=100)},
          {"name": "MLP Classifier", "clf": MLPClassifier(solver='adam', alpha=1e-1, hidden_layer_sizes=(10,10,5,2), max_iter=500, random_state=42)},
          {"name": "Gradient Boosting", "clf": GradientBoostingClassifier()},
          {"name": "LGBM Gradient Boosting", "clf": lgb.LGBMClassifier()}
        ]

for model in tqdm(models):
    print(model["name"])
    model_details = train_model(model, X_train_sc, y_train, X_test_sc, y_test) 
    trained_models.append(model_details)
# Out:
#   0%|          | 0/6 [00:00<?, ?it/s]
# Logistic Regression
# Decision Tree
# Random Forest
# MLP Classifier
# Gradient Boosting
# LGBM Gradient Boosting

# %%
model_df = pd.DataFrame(trained_models).sort_values(by = "weighted_fp", ascending= False)
model_df
# Out:
#                      name                                              model  \
# 5  LGBM Gradient Boosting                                   LGBMClassifier()
# 2           Random Forest  (DecisionTreeClassifier(max_features='auto', r...
# 4       Gradient Boosting  ([DecisionTreeRegressor(criterion='friedman_ms...
# 1           Decision Tree                           DecisionTreeClassifier()
# 3          MLP Classifier  MLPClassifier(alpha=0.1, hidden_layer_sizes=(1...
# 0     Logistic Regression                               LogisticRegression()
#
#    train_accuracy  test_accuracy  train_time  precision    recall        f1  \
# 5        0.915191       0.913326    9.091767   0.372082  0.107009  0.166215
# 2        0.999990       0.896980   24.973572   0.253241  0.141649  0.181677
# 4        0.898004       0.892460  308.856247   0.248526  0.164071  0.197655
# 1        1.000000       0.771652   13.613170   0.121890  0.294710  0.172454
# 3        0.758414       0.714647  128.509496   0.159272  0.592374  0.251046
# 0        0.691601       0.686485    1.811956   0.157113  0.660580  0.253850
#
#     weighted_fp    rocauc
# 5  -8430.684211  0.545574
# 2  -8866.157895  0.552483
# 4  -8971.473684  0.560250
# 1 -12337.315789  0.554125
# 3 -13648.000000  0.658879
# 0 -14388.210526  0.674670

# %% [markdown]
# ### Using data

# %%
data2.shape
# Out:
# (307511, 150)

# %%
X2 = data2.drop(['SK_ID_CURR', 'TARGET'], axis=1)
y2 = data2.TARGET

X_train2, X_test2, y_train2, y_test2 = train_test_split(X2, y2, test_size=0.3, stratify = y2,  random_state=42)

SC = StandardScaler()
X_train2_sc = SC.fit_transform(X_train2)
X_test2_sc = SC.transform(X_test2)

# %% [markdown]
# #### Oversampling / Undersampling

# %%
print(Counter(y_train2))
print(Counter(y_train2)[0]/Counter(y_train2)[1])
# Out:
# Counter({0.0: 197880, 1.0: 17377})
# 11.38746619094205

# %%
under = RandomUnderSampler(sampling_strategy=1)
over = SMOTE(sampling_strategy=0.5)

steps = [('o', over),('u', under)]
osus = Pipeline(steps=steps)

X_train2_sc, y_train2 = osus.fit_resample(X_train2_sc, y_train2)

print(Counter(y_train2))
print(Counter(y_train2)[0]/Counter(y_train2)[1])
# Out:
# Counter({0.0: 98940, 1.0: 98940})
# 1.0

# %% [markdown]
# #### Training

# %%
trained_models2 = [] #  keep track of all details for models we train
models2 = [
          {"name": "Logistic Regression", "clf": LogisticRegression()}, 
          {"name": "Decision Tree", "clf": DecisionTreeClassifier()},
          {"name": "Random Forest", "clf": RandomForestClassifier(n_estimators=100)}, 
          {"name": "MLP Classifier", "clf": MLPClassifier(solver='adam', alpha=1e-1, hidden_layer_sizes=(10,10,5,2), max_iter=500, random_state=42)},
          {"name": "Gradient Boosting", "clf": GradientBoostingClassifier()},
          {"name": "LGBM Gradient Boosting", "clf": lgb.LGBMClassifier()}
        ]

for model in tqdm(models2):
    print(model["name"])
    model_details = train_model(model, X_train2_sc, y_train2, X_test2_sc, y_test2) 
    trained_models2.append(model_details)
# Out:
#   0%|          | 0/6 [00:00<?, ?it/s]
# Logistic Regression
# Decision Tree
# Random Forest
# MLP Classifier
# Gradient Boosting
# LGBM Gradient Boosting

# %%
model_df2 = pd.DataFrame(trained_models2).sort_values(by = "weighted_fp", ascending= False)

# %%
model_df["data"] = "Application_train"
model_df2["data"] = "Data2"

# %%
model_results = model_df.append(model_df2).sort_values(by = "weighted_fp", ascending= False).reset_index(drop = True)
model_results
# Out:
#                       name                                              model  \
# 0   LGBM Gradient Boosting                                   LGBMClassifier()
# 1   LGBM Gradient Boosting                                   LGBMClassifier()
# 2            Random Forest  (DecisionTreeClassifier(max_features='auto', r...
# 3            Random Forest  (DecisionTreeClassifier(max_features='auto', r...
# 4        Gradient Boosting  ([DecisionTreeRegressor(criterion='friedman_ms...
# 5        Gradient Boosting  ([DecisionTreeRegressor(criterion='friedman_ms...
# 6            Decision Tree                           DecisionTreeClassifier()
# 7            Decision Tree                           DecisionTreeClassifier()
# 8           MLP Classifier  MLPClassifier(alpha=0.1, hidden_layer_sizes=(1...
# 9           MLP Classifier  MLPClassifier(alpha=0.1, hidden_layer_sizes=(1...
# 10     Logistic Regression                               LogisticRegression()
# 11     Logistic Regression                               LogisticRegression()
#
#     train_accuracy  test_accuracy  train_time  precision    recall        f1  \
# 0         0.916844       0.913370   15.224074   0.385714  0.123255  0.186813
# 1         0.915191       0.913326    9.091767   0.372082  0.107009  0.166215
# 2         0.999965       0.897999   34.388205   0.252897  0.134801  0.175863
# 3         0.999990       0.896980   24.973572   0.253241  0.141649  0.181677
# 4         0.902037       0.895343  571.346885   0.268610  0.171992  0.209708
# 5         0.898004       0.892460  308.856247   0.248526  0.164071  0.197655
# 6         1.000000       0.771652   13.613170   0.121890  0.294710  0.172454
# 7         1.000000       0.768650   27.529169   0.123992  0.307599  0.176741
# 8         0.774737       0.731903  138.436086   0.166094  0.577202  0.257958
# 9         0.758414       0.714647  128.509496   0.159272  0.592374  0.251046
# 10        0.709066       0.696067    3.225145   0.163006  0.668636  0.262112
# 11        0.691601       0.686485    1.811956   0.157113  0.660580  0.253850
#
#      weighted_fp    rocauc               data
# 0   -8410.315789  0.553008              Data2
# 1   -8430.684211  0.545574  Application_train
# 2   -8844.526316  0.549914              Data2
# 3   -8866.157895  0.552483  Application_train
# 4   -8878.157895  0.565432              Data2
# 5   -8971.473684  0.560250  Application_train
# 6  -12337.315789  0.554125  Application_train
# 7  -12409.631579  0.558370              Data2
# 8  -13163.105263  0.661346              Data2
# 9  -13648.000000  0.658879  Application_train
# 10 -14099.578947  0.683556              Data2
# 11 -14388.210526  0.674670  Application_train

# %%
fig, (ax1, ax2, ax3, ax4, ax5) = plt.subplots(1,5, figsize = (20,5))
sns.barplot(x="weighted_fp", y= "name", data=model_results, ax = ax1) 
sns.barplot(x="precision", y= "name", data=model_results, ax = ax2) 
sns.barplot(x="recall", y= "name", data=model_results, ax = ax3) 
sns.barplot(x="f1", y= "name", data=model_results, ax = ax4) 
sns.barplot(x="rocauc", y= "name", data=model_results, ax = ax5) 

ax1.set_title("Weighted_fp", weight ="bold")
ax2.set_title("Precision", weight ="bold")
ax3.set_title("Recall", weight ="bold")
ax4.set_title("f1-score", weight ="bold")
ax5.set_title("ROC AUC", weight ="bold")

ax1.set(xlabel="", ylabel="")
ax2.set(xlabel="", ylabel="", yticklabels=[])
ax3.set(xlabel="", ylabel="", yticklabels=[])
ax4.set(xlabel="", ylabel="", yticklabels=[])
ax5.set(xlabel="", ylabel="", yticklabels=[])

fig.suptitle("Comparaison données de test", weight ="bold")
plt.show()

# %%
with open('trained_models.pickle', 'wb') as f:
    pickle.dump(trained_models, f)

# %%
with open('trained_models2.pickle', 'wb') as f:
    pickle.dump(trained_models2, f)

# %% [markdown]
# ### Optimisation

# %%
cv_columns= ['params','data',
       'param_learning_rate', 'param_max_depth', 'param_min_child_samples',
       'param_min_child_weight', 'param_min_split_gain', 'param_num_leaves',
        'mean_fit_time', 'mean_score_time', 'mean_test_score', 'rank_test_score']

# %% [markdown]
# #### Test App_train VS Data2

# %%
params_lgb_light = { 
    'learning_rate':[0.05], 
    'num_leaves':[2, 3, 4], 
    'min_split_gain':[0.01],
    'max_depth':[2, 3, 4],
    'min_child_samples': [100],
    'min_child_weight':[0.01]
    }

# %%
cv2_train = GridSearchCV(lgb.LGBMClassifier(),
                         param_grid=params_lgb_light,
                         scoring="roc_auc",
                         n_jobs=-1,
                         cv=5,
                         verbose=10)

start = time.time()
cv2_train.fit(X_train_sc, y_train)
time.time() - start
# Out:
# Fitting 5 folds for each of 9 candidates, totalling 45 fits
# 138.00369954109192

# %%
cv2_data = GridSearchCV(lgb.LGBMClassifier(),
                        param_grid=params_lgb_light,
                        scoring="roc_auc",
                        n_jobs=-1,
                        cv=5,
                        verbose=10)

start = time.time()
cv2_data.fit(X_train2_sc, y_train2)
time.time() - start
# Out:
# Fitting 5 folds for each of 9 candidates, totalling 45 fits
# 234.05813717842102

# %%
cv2_train_results = pd.DataFrame(cv2_train.cv_results_)
cv2_train_results["data"] = "Application_train"

cv2_data_results = pd.DataFrame(cv2_data.cv_results_)
cv2_data_results["data"] = "Data2"

cv2_results = cv2_data_results.append(cv2_train_results)
cv2_results[cv_columns].sort_values(by="mean_test_score", ascending=False).reset_index(drop=True)
# Out:
#                                                params               data  \
# 0   {'learning_rate': 0.05, 'max_depth': 3, 'min_c...              Data2
# 1   {'learning_rate': 0.05, 'max_depth': 4, 'min_c...              Data2
# 2   {'learning_rate': 0.05, 'max_depth': 2, 'min_c...              Data2
# 3   {'learning_rate': 0.05, 'max_depth': 3, 'min_c...              Data2
# 4   {'learning_rate': 0.05, 'max_depth': 4, 'min_c...              Data2
# 5   {'learning_rate': 0.05, 'max_depth': 2, 'min_c...              Data2
# 6   {'learning_rate': 0.05, 'max_depth': 4, 'min_c...  Application_train
# 7   {'learning_rate': 0.05, 'max_depth': 3, 'min_c...  Application_train
# 8   {'learning_rate': 0.05, 'max_depth': 2, 'min_c...  Application_train
# 9   {'learning_rate': 0.05, 'max_depth': 3, 'min_c...  Application_train
# 10  {'learning_rate': 0.05, 'max_depth': 4, 'min_c...  Application_train
# 11  {'learning_rate': 0.05, 'max_depth': 2, 'min_c...  Application_train
# 12  {'learning_rate': 0.05, 'max_depth': 2, 'min_c...              Data2
# 13  {'learning_rate': 0.05, 'max_depth': 4, 'min_c...              Data2
# 14  {'learning_rate': 0.05, 'max_depth': 3, 'min_c...              Data2
# 15  {'learning_rate': 0.05, 'max_depth': 3, 'min_c...  Application_train
# 16  {'learning_rate': 0.05, 'max_depth': 4, 'min_c...  Application_train
# 17  {'learning_rate': 0.05, 'max_depth': 2, 'min_c...  Application_train
#
#    param_learning_rate param_max_depth param_min_child_samples  \
# 0                 0.05               3                     100
# 1                 0.05               4                     100
# 2                 0.05               2                     100
# 3                 0.05               3                     100
# 4                 0.05               4                     100
# 5                 0.05               2                     100
# 6                 0.05               4                     100
# 7                 0.05               3                     100
# 8                 0.05               2                     100
# 9                 0.05               3                     100
# 10                0.05               4                     100
# 11                0.05               2                     100
# 12                0.05               2                     100
# 13                0.05               4                     100
# 14                0.05               3                     100
# 15                0.05               3                     100
# 16                0.05               4                     100
# 17                0.05               2                     100
#
#    param_min_child_weight param_min_split_gain param_num_leaves  \
# 0                    0.01                 0.01                4
# 1                    0.01                 0.01                4
# 2                    0.01                 0.01                4
# 3                    0.01                 0.01                3
# 4                    0.01                 0.01                3
# 5                    0.01                 0.01                3
# 6                    0.01                 0.01                4
# 7                    0.01                 0.01                4
# 8                    0.01                 0.01                4
# 9                    0.01                 0.01                3
# 10                   0.01                 0.01                3
# 11                   0.01                 0.01                3
# 12                   0.01                 0.01                2
# 13                   0.01                 0.01                2
# 14                   0.01                 0.01                2
# 15                   0.01                 0.01                2
# 16                   0.01                 0.01                2
# 17                   0.01                 0.01                2
#
#     mean_fit_time  mean_score_time  mean_test_score  rank_test_score
# 0       41.077497         0.720793         0.920948                1
# 1       30.210032         0.357299         0.920948                1
# 2       34.781147         0.536271         0.915628                3
# 3       39.776802         0.615621         0.910310                4
# 4       38.727280         0.550622         0.910310                4
# 5       35.037208         0.571874         0.910310                4
# 6       16.057307         0.313431         0.910211                1
# 7       20.380036         0.544597         0.910211                1
# 8       19.268855         0.476692         0.897390                3
# 9       19.997481         0.435945         0.889016                4
# 10      19.768044         0.401484         0.889016                4
# 11      26.651224         0.649053         0.889016                4
# 12      32.107479         0.469947         0.842752                7
# 13      34.215522         0.525521         0.842752                7
# 14      34.131245         0.558703         0.842752                7
# 15      16.063380         0.451395         0.806507                7
# 16      17.697829         0.389853         0.806507                7
# 17      27.774797         0.372685         0.806507                7

# %%
sns.scatterplot(x = cv2_results["rank_test_score"], y = cv2_results["mean_test_score"], hue = cv2_results["data"])
# Out:
# <AxesSubplot:xlabel='rank_test_score', ylabel='mean_test_score'>

# %% [markdown]
# #### Test Scorer Weighted_fp_score

# %%
cv2_train_fp = GridSearchCV(lgb.LGBMClassifier(), param_grid= params_lgb_light ,scoring= weighted_fp_score, n_jobs=-1, cv=5 ,verbose=10)

start = time.time()
cv2_train_fp.fit(X_train2_sc, y_train2)
time.time() - start
# Out:
# Fitting 5 folds for each of 9 candidates, totalling 45 fits
# 161.10481548309326

# %%
cv2_train_fp_results = pd.DataFrame(cv2_train_fp.cv_results_)
cv2_train_fp_results
# Out:
#    mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0      11.216146      0.683518         0.552079        0.087421
# 1      10.691646      0.617747         0.485120        0.082061
# 2      10.082794      0.494124         0.275253        0.025610
#
#   param_learning_rate param_max_depth param_min_child_samples  \
# 0                0.05               2                     100
# 1                0.05               3                     100
# 2                0.05               4                     100
#
#   param_min_child_weight param_min_split_gain param_num_leaves  \
# 0                   0.01                 0.01                2
# 1                   0.01                 0.01                2
# 2                   0.01                 0.01                2
#
#                                               params  split0_test_score  \
# 0  {'learning_rate': 0.05, 'max_depth': 2, 'min_c...       -9101.368421
# 1  {'learning_rate': 0.05, 'max_depth': 3, 'min_c...       -9101.368421
# 2  {'learning_rate': 0.05, 'max_depth': 4, 'min_c...       -9101.368421
#
#    split1_test_score  split2_test_score  split3_test_score  split4_test_score  \
# 0       -4814.210526       -4806.947368       -4782.157895       -4753.263158
# 1       -4814.210526       -4806.947368       -4782.157895       -4753.263158
# 2       -4814.210526       -4806.947368       -4782.157895       -4753.263158
#
#    mean_test_score  std_test_score  rank_test_score
# 0     -5651.589474      1725.02174                1
# 1     -5651.589474      1725.02174                1
# 2     -5651.589474      1725.02174                1

# %% [markdown]
# #### Test RandomizedSearchCV

# %%
rs = RandomizedSearchCV(lgb.LGBMClassifier(), param_distributions=params_lgb_light, scoring=weighted_fp_score, n_jobs=-1, cv=5 ,verbose=10)

start = time.time()
rs.fit(X_train2_sc,y_train2)
time.time() - start
# Out:
# Fitting 5 folds for each of 9 candidates, totalling 45 fits
# 254.96405220031738

# %%
rs_results = pd.DataFrame(rs.cv_results_).sort_values(by="mean_test_score", ascending=False).reset_index(drop=True)
rs_results["data"] = "Data2"
rs_results[cv_columns]
# Out:
#                                               params   data  \
# 0  {'num_leaves': 4, 'min_split_gain': 0.01, 'min...  Data2
# 1  {'num_leaves': 4, 'min_split_gain': 0.01, 'min...  Data2
# 2  {'num_leaves': 4, 'min_split_gain': 0.01, 'min...  Data2
# 3  {'num_leaves': 3, 'min_split_gain': 0.01, 'min...  Data2
# 4  {'num_leaves': 3, 'min_split_gain': 0.01, 'min...  Data2
# 5  {'num_leaves': 3, 'min_split_gain': 0.01, 'min...  Data2
# 6  {'num_leaves': 2, 'min_split_gain': 0.01, 'min...  Data2
# 7  {'num_leaves': 2, 'min_split_gain': 0.01, 'min...  Data2
# 8  {'num_leaves': 2, 'min_split_gain': 0.01, 'min...  Data2
#
#   param_learning_rate param_max_depth param_min_child_samples  \
# 0                0.05               3                     100
# 1                0.05               4                     100
# 2                0.05               2                     100
# 3                0.05               2                     100
# 4                0.05               3                     100
# 5                0.05               4                     100
# 6                0.05               2                     100
# 7                0.05               3                     100
# 8                0.05               4                     100
#
#   param_min_child_weight param_min_split_gain param_num_leaves  mean_fit_time  \
# 0                   0.01                 0.01                4      42.298935
# 1                   0.01                 0.01                4      30.154095
# 2                   0.01                 0.01                4      39.727177
# 3                   0.01                 0.01                3      46.501622
# 4                   0.01                 0.01                3      41.161651
# 5                   0.01                 0.01                3      39.987989
# 6                   0.01                 0.01                2      39.747520
# 7                   0.01                 0.01                2      36.541060
# 8                   0.01                 0.01                2      35.045003
#
#    mean_score_time  mean_test_score  rank_test_score
# 0         0.794515     -4662.410526                1
# 1         0.419726     -4662.410526                1
# 2         0.914507     -4780.389474                3
# 3         0.919661     -4898.368421                4
# 4         0.739963     -4898.368421                4
# 5         0.630395     -4898.368421                4
# 6         0.767702     -5697.000000                7
# 7         0.670023     -5697.000000                7
# 8         0.620428     -5697.000000                7

# %% [markdown]
# #### In-depth Opti

# %%
params_lgb = { 
            'learning_rate':[0.05, 0.1, 0.5], 
            'max_depth':[2 , 4 , 6],
            'min_child_samples': [100,300,500],
            'min_split_gain':[0.01, 0.05],
            'num_leaves':[2,12,48], 
            'min_child_weight':[0.01 ,0.05, 0.1]
            }

# %%
cv = GridSearchCV(lgb.LGBMClassifier(), param_grid= params_lgb ,scoring= weighted_fp_score, n_jobs=-1, cv=5, verbose=10)

# %%
cv.fit(X_train2_sc,y_train2)
# Out:
# Fitting 5 folds for each of 486 candidates, totalling 2430 fits
# GridSearchCV(cv=5, estimator=LGBMClassifier(), n_jobs=-1,
#              param_grid={'learning_rate': [0.05, 0.1, 0.5],
#                          'max_depth': [2, 4, 6],
#                          'min_child_samples': [100, 300, 500],
#                          'min_child_weight': [0.01, 0.05, 0.1],
#                          'min_split_gain': [0.01, 0.05],
#                          'num_leaves': [2, 12, 48]},
#              scoring=make_scorer(weighted_fp), verbose=10)

# %%
cv.best_estimator_
# Out:
# LGBMClassifier(max_depth=6, min_child_samples=500, min_child_weight=0.01,
#                min_split_gain=0.05, num_leaves=48)

# %%
cv_results = pd.DataFrame(cv.cv_results_).sort_values(by="mean_test_score", ascending=False).reset_index(drop=True)
cv_results["data"] = "Data2"
cv_results[cv_columns].head(10)
# Out:
#                                               params   data  \
# 0  {'learning_rate': 0.1, 'max_depth': 6, 'min_ch...  Data2
# 1  {'learning_rate': 0.1, 'max_depth': 6, 'min_ch...  Data2
# 2  {'learning_rate': 0.1, 'max_depth': 6, 'min_ch...  Data2
# 3  {'learning_rate': 0.1, 'max_depth': 6, 'min_ch...  Data2
# 4  {'learning_rate': 0.1, 'max_depth': 6, 'min_ch...  Data2
# 5  {'learning_rate': 0.1, 'max_depth': 6, 'min_ch...  Data2
# 6  {'learning_rate': 0.1, 'max_depth': 6, 'min_ch...  Data2
# 7  {'learning_rate': 0.1, 'max_depth': 6, 'min_ch...  Data2
# 8  {'learning_rate': 0.1, 'max_depth': 6, 'min_ch...  Data2
# 9  {'learning_rate': 0.1, 'max_depth': 6, 'min_ch...  Data2
#
#   param_learning_rate param_max_depth param_min_child_samples  \
# 0                 0.1               6                     500
# 1                 0.1               6                     500
# 2                 0.1               6                     500
# 3                 0.1               6                     500
# 4                 0.1               6                     500
# 5                 0.1               6                     500
# 6                 0.1               6                     300
# 7                 0.1               6                     300
# 8                 0.1               6                     300
# 9                 0.1               6                     300
#
#   param_min_child_weight param_min_split_gain param_num_leaves  mean_fit_time  \
# 0                    0.1                 0.05               48      39.738072
# 1                   0.05                 0.05               48      40.390897
# 2                   0.01                 0.05               48      39.912971
# 3                    0.1                 0.01               48      40.095469
# 4                   0.05                 0.01               48      39.510803
# 5                   0.01                 0.01               48      40.600572
# 6                    0.1                 0.01               48      40.912199
# 7                   0.01                 0.01               48      40.862821
# 8                   0.05                 0.01               48      40.374302
# 9                   0.01                 0.05               48      42.068927
#
#    mean_score_time  mean_test_score  rank_test_score
# 0         0.917471     -3908.557895                1
# 1         0.838517     -3908.557895                1
# 2         0.881493     -3908.557895                1
# 3         0.847110     -3908.621053                4
# 4         0.882091     -3908.621053                4
# 5         0.886090     -3908.621053                4
# 6         0.876093     -3910.894737                7
# 7         0.924668     -3910.894737                7
# 8         0.903082     -3910.894737                7
# 9         0.869299     -3911.400000               10

# %%
cv_results.loc[1].params
# Out:
# {'learning_rate': 0.1,
#  'max_depth': 6,
#  'min_child_samples': 500,
#  'min_child_weight': 0.05,
#  'min_split_gain': 0.05,
#  'num_leaves': 48}

# %%
sns.scatterplot(x = cv_results["rank_test_score"], y = cv_results["mean_test_score"], hue = cv_results["param_max_depth"], palette = "viridis")
plt.show()
sns.scatterplot(x = cv_results["rank_test_score"], y = cv_results["mean_test_score"], hue = cv_results["param_min_child_samples"], palette = "viridis")
plt.show()
sns.scatterplot(x = cv_results["rank_test_score"], y = cv_results["mean_test_score"], hue = cv_results["param_learning_rate"], palette = "viridis")
plt.show()

# %%
params_opti = {'learning_rate': 0.1,
 'max_depth': 6,
 'min_child_samples': 500,
 'min_child_weight': 0.05,
 'min_split_gain': 0.05,
 'num_leaves': 48}

# %%
model_opti = LGBMClassifier(**params_opti)

# %%
X_train2_sc_pd = pd.DataFrame(X_train2_sc, columns= X_train2.columns)
X_test2_sc_pd = pd.DataFrame(X_test2_sc, columns= X_train2.columns)

# %%
model_opti.fit(X_train2_sc_pd, y_train2)
# Out:
# LGBMClassifier(max_depth=6, min_child_samples=500, min_child_weight=0.05,
#                min_split_gain=0.05, num_leaves=48)

# %%
model_opti.get_params
# Out:
# <bound method LGBMModel.get_params of LGBMClassifier(max_depth=6, min_child_samples=500, min_child_weight=0.05,
#                min_split_gain=0.05, num_leaves=48)>

# %% [markdown]
# ### Feature importance

# %% [markdown]
# #### Sklearn

# %%
feature_names = X_train2.columns
y_ticks = np.arange(0, len(feature_names))
tree_feature_importances = model_opti.feature_importances_
sorted_idx = model_opti.feature_importances_.argsort()

fig, ax = plt.subplots(figsize = (6,6))
plt.barh(y_ticks[-20:],tree_feature_importances[sorted_idx][-20:])
ax.set_yticks(y_ticks[-20:])
ax.set_yticklabels(feature_names[sorted_idx][-20:])
ax.set_title("Poids des features : " +str(model_opti) , weight = "bold")
ax.set_ylabel('', weight = "bold")
plt.show()

# %% [markdown]
# #### LGBM

# %%
lgb.plot_importance(model_opti, height=0.5, max_num_features=20, ignore_zero = False, figsize = (12,6), importance_type ='gain')
plt.show()

# %% [markdown]
# #### Shap

# %%
shap.initjs()
# Out:
# <div align='center'><img src='data:image/png;base64,...' /></div><script charset='utf-8'>!function(t){function e(r){if(n[r])return n[r].exports;var i=n[r]={i:r,l:!1,exports:{}};return t[r].call(i.exports,i,i.exports,e),i.l=!0,i.exports}var n={};return e.m=t,e.c=n,e.i=function(t){return t},e.d=function(t,n,r){e.o(t,n)||Object.defineProperty(t,n,{configurable:!1,enumerable:!0,get:r})},e.n=function(t){var n=t&&t.__esModule?function(){return t.default}:function(){return t};return e.d(n,"a",n),n},e.o=function(t,e){return Object.prototype.hasOwnProperty.call(t,e)},e.p="",e(e.s=410)}([function(t,e,n){"use strict";function r(t,e,n,r,o,a,u,c){if(i(e),!t){var s;if(void 0===e)s=new Error("Minified exception occurred; use the non-minified dev environment for the full error message and additional helpful warnings.");else{var l=[n,r,o,a,u,c],f=0;s=new Error(e.replace(/%s/g,function(){return l[f++]})),s.name="Invariant Violation"}throw s.framesToPop=1,s}}var i=function(t){};t.exports=r},function(t,e,n){"use strict";var r=n(8),i=r;t.exports=i},function(t,e,n){"use strict";function r(t){for(var e=arguments.length-1,n="Minified React error #"+t+"; visit http://facebook.github.io/react/docs/error-decoder.html?invariant="+t,r=0;r<e;r++)n+="&args[]="+encodeURIComponent(arguments[r+1]);n+=" for the full message or use the non-minified dev environment for full errors and additional helpful warnings.";var i=new Error(n);throw i.name="Invariant Violation",i.framesToPop=1,i}t.exports=r},function(t,e,n){"use strict";function r(t){if(null===t||void 0===t)throw new TypeError("Object.assign cannot be called with null or undefined");return Object(t)}function i(){try{if(!Object.assign)return!1;var t=new String("abc");if(t[5]="de","5"===Object.getOwnPropertyNames(t)[0])return!1;for(var e={},n=0;n<10;n++)e["_"+String.fromCharCode(n)]=n;var r=Object.getOwnPropertyNames(e).map(function(t){return e[t]});if("0123456789"!==r.join(""))return!1;var i={};return"abcdefghijklmnopqrst".split("").forEach(function(t){i[t]=t}),"abcdefghijklmnopqrst"===Object.keys(Object.assign({},i)).join("")}catch(t){return!1}}/*
# object-assign
# (c) Sindre Sorhus
# @license MIT
# */
# var o=Object.getOwnPropertySymbols,a=Object.prototype.hasOwnProperty,u=Object.prototype.propertyIsEnumerable;t.exports=i()?Object.assign:function(t,e){for(var n,i,c=r(t),s=1;s<arguments.length;s++){n=Object(arguments[s]);for(var l in n)a.call(n,l)&&(c[l]=n[l]);if(o){i=o(n);for(var f=0;f<i.length;f++)u.call(n,i[f])&&(c[i[f]]=n[i[f]])}}return c}},function(t,e,n){"use strict";function r(t,e){return 1===t.nodeType&&t.getAttribute(d)===String(e)||8===t.nodeType&&t.nodeValue===" react-text: "+e+" "||8===t.nodeType&&t.nodeValue===" react-empty: "+e+" "}function i(t){for(var e;e=t._renderedComponent;)t=e;return t}function o(t,e){var n=i(t);n._hostNode=e,e[g]=n}function a(t){var e=t._hostNode;e&&(delete e[g],t._hostNode=null)}function u(t,e){if(!(t._flags&v.hasCachedChildNodes)){var n=t._renderedChildren,a=e.firstChild;t:for(var u in n)if(n.hasOwnProperty(u)){var c=n[u],s=i(c)._domID;if(0!==s){for(;null!==a;a=a.nextSibling)if(r(a,s)){o(c,a);continue t}f("32",s)}}t._flags|=v.hasCachedChildNodes}}function c(t){if(t[g])return t[g];for(var e=[];!t[g];){if(e.push(t),!t.parentNode)return null;t=t.parentNode}for(var n,r;t&&(r=t[g]);t=e.pop())n=r,e.length&&u(r,t);return n}function s(t){var e=c(t);return null!=e&&e._hostNode===t?e:null}function l(t){if(void 0===t._hostNode?f("33"):void 0,t._hostNode)return t._hostNode;for(var e=[];!t._hostNode;)e.push(t),t._hostParent?void 0:f("34"),t=t._hostParent;for(;e.length;t=e.pop())u(t,t._hostNode);return t._hostNode}var f=n(2),p=n(21),h=n(157),d=(n(0),p.ID_ATTRIBUTE_NAME),v=h,g="__reactInternalInstance$"+Math.random().toString(36).slice(2),m={getClosestInstanceFromNode:c,getInstanceFromNode:s,getNodeFromInstance:l,precacheChildNodes:u,precacheNode:o,uncacheNode:a};t.exports=m},function(t,e,n){"use strict";function r(t,e,n,a){function u(e){return t(e=new Date(+e)),e}return u.floor=u,u.ceil=function(n){return t(n=new Date(n-1)),e(n,1),t(n),n},u.round=function(t){var e=u(t),n=u.ceil(t);return t-e<n-t?e:n},u.offset=function(t,n){return e(t=new Date(+t),null==n?1:Math.floor(n)),t},u.range=function(n,r,i){var o=[];if(n=u.ceil(n),i=null==i?1:Math.floor(i),!(n<r&&i>0))return o;do o.push(new Date(+n));while(e(n,i),t(n),n<r);return o},u.filter=function(n){return r(function(e){if(e>=e)for(;t(e),!n(e);)e.setTime(e-1)},function(t,r){if(t>=t)for(;--r>=0;)for(;e(t,1),!n(t););})},n&&(u.count=function(e,r){return i.setTime(+e),o.setTime(+r),t(i),t(o),Math.floor(n(i,o))},u.every=function(t){return t=Math.floor(t),isFinite(t)&&t>0?t>1?u.filter(a?function(e){return a(e)%t===0}:function(e){return u.count(0,e)%t===0}):u:null}),u}e.a=r;var i=new Date,o=new Date},function(t,e,n){"use strict";var r=!("undefined"==typeof window||!window.document||!window.document.createElement),i={canUseDOM:r,canUseWorkers:"undefined"!=typeof Worker,canUseEventListeners:r&&!(!window.addEventListener&&!window.attachEvent),canUseViewport:r&&!!window.screen,isInWorker:!r};t.exports=i},function(t,e,n){"use strict";function r(t,e){this._groups=t,this._parents=e}function i(){return new r([[document.documentElement]],D)}var o=n(272),a=n(273),u=n(261),c=n(255),s=n(131),l=n(260),f=n(265),p=n(268),h=n(275),d=n(253),v=n(267),g=n(266),m=n(274),y=n(259),_=n(258),b=n(252),x=n(276),w=n(269),C=n(254),M=n(277),k=n(262),E=n(270),T=n(264),S=n(251),P=n(263),N=n(271),A=n(256),O=n(70),I=n(257);n.d(e,"c",function(){return D}),e.b=r;var D=[null];r.prototype=i.prototype={constructor:r,select:o.a,selectAll:a.a,filter:u.a,data:c.a,enter:s.a,exit:l.a,merge:f.a,order:p.a,sort:h.a,call:d.a,nodes:v.a,node:g.a,size:m.a,empty:y.a,each:_.a,attr:b.a,style:x.a,property:w.a,classed:C.a,text:M.a,html:k.a,raise:E.a,lower:T.a,append:S.a,insert:P.a,remove:N.a,datum:A.a,on:O.c,dispatch:I.a},e.a=i},function(t,e,n){"use strict";function r(t){return function(){return t}}var i=function(){};i.thatReturns=r,i.thatReturnsFalse=r(!1),i.thatReturnsTrue=r(!0),i.thatReturnsNull=r(null),i.thatReturnsThis=function(){return this},i.thatReturnsArgument=function(t){return t},t.exports=i},function(t,e,n ...

# %% [markdown]
# ##### KernelExplainer

# %%
explainer = shap.KernelExplainer(model_opti.predict_proba, shap.sample(X_train2_sc_pd, 1000))
# Out:
# WARNING:shap:Using 1000 background data samples could cause slower run times. Consider using shap.sample(data, K) or shap.kmeans(data, K) to summarize the background as K samples.

# %%
row_to_show = 5
data_for_prediction = X_test2_sc_pd.iloc[row_to_show]  # use 1 row of data here. Could use multiple rows if desired
data_for_prediction_array = data_for_prediction.values.reshape(1, -1)
print(model_opti.predict_proba(data_for_prediction_array))

shap_values_i = explainer.shap_values(data_for_prediction)
print(explainer.expected_value)

print('i  = 0')
shap.force_plot(explainer.expected_value[0], shap_values_i[0], data_for_prediction)
# Out:
# [[0.48742429 0.51257571]]
# [0.52200136 0.47799864]
# i  = 0
# <div id='iULO5K33815MLZGZJK3VS'>
# <div style='color: #900; text-align: center;'>
#   <b>Visualization omitted, Javascript library not loaded!</b><br>
#   Have you run `initjs()` in this notebook? If this notebook was from another
#   user you must also trust this notebook (File -> Trust notebook). If you are viewing
#   this notebook on github the Javascript has been stripped for security. If you are using
#   JupyterLab this error is because a JupyterLab extension has not yet been written.
# </div></div>
#  <script>
#    if (window.SHAP) SHAP.ReactDom.render(
#     SHAP.React.createElement(SHAP.AdditiveForceVisualizer, {"outNames": ["f(x)"], "baseValue": 0.5220013569901695, "outValue": 0.4874242856883111, "link": "identity", "featureNames": ["NAME_CONTRACT_TYPE", "CODE_GENDER", "FLAG_OWN_CAR", "FLAG_OWN_REALTY", "AMT_INCOME_TOTAL", "AMT_GOODS_PRICE", "NAME_TYPE_SUITE", "NAME_INCOME_TYPE", "NAME_EDUCATION_TYPE", "NAME_FAMILY_STATUS", "NAME_HOUSING_TYPE", "REGION_POPULATION_RELATIVE", "DAYS_ID_PUBLISH", "OWN_CAR_AGE", "FLAG_MOBIL", "FLAG_EMP_PHONE", "FLAG_WORK_PHONE", "FLAG_CONT_MOBILE", "FLAG_PHONE", "FLAG_EMAIL", "OCCUPATION_TYPE", "REGION_RATING_CLIENT", "REGION_RATING_CLIENT_W_CITY", "WEEKDAY_APPR_PROCESS_START", "HOUR_APPR_PROCESS_START", "REG_REGION_NOT_LIVE_REGION", "REG_REGION_NOT_WORK_REGION", "LIVE_REGION_NOT_WORK_REGION", "REG_CITY_NOT_LIVE_CITY", "REG_CITY_NOT_WORK_CITY", "LIVE_CITY_NOT_WORK_CITY", "ORGANIZATION_TYPE", "EXT_SOURCE_1", "EXT_SOURCE_2", "EXT_SOURCE_3", "APARTMENTS_MODE", "BASEMENTAREA_MODE", "YEARS_BEGINEXPLUATATION_MODE", "YEARS_BUILD_MODE", "COMMONAREA_MODE", "ELEVATORS_MODE", "ENTRANCES_MODE", "FLOORSMAX_MODE", "FLOORSMIN_MODE", "LANDAREA_MODE", "LIVINGAPARTMENTS_MODE", "LIVINGAREA_MODE", "NONLIVINGAPARTMENTS_MODE", "NONLIVINGAREA_MODE", "APARTMENTS_MEDI", "BASEMENTAREA_MEDI", "YEARS_BEGINEXPLUATATION_MEDI", "YEARS_BUILD_MEDI", "COMMONAREA_MEDI", "ELEVATORS_MEDI", "ENTRANCES_MEDI", "FLOORSMAX_MEDI", "FLOORSMIN_MEDI", "LANDAREA_MEDI", "LIVINGAPARTMENTS_MEDI", "LIVINGAREA_MEDI", "NONLIVINGAPARTMENTS_MEDI", "NONLIVINGAREA_MEDI", "FONDKAPREMONT_MODE", "HOUSETYPE_MODE", "TOTALAREA_MODE", "WALLSMATERIAL_MODE", "EMERGENCYSTATE_MODE", "OBS_30_CNT_SOCIAL_CIRCLE", "DEF_30_CNT_SOCIAL_CIRCLE", "OBS_60_CNT_SOCIAL_CIRCLE", "DEF_60_CNT_SOCIAL_CIRCLE", "DAYS_LAST_PHONE_CHANGE", "SK_ID_BUREAU", "DAYS_CREDIT", "CREDIT_DAY_OVERDUE", "DAYS_CREDIT_ENDDATE", "DAYS_ENDDATE_FACT", "AMT_CREDIT_MAX_OVERDUE", "CNT_CREDIT_PROLONG", "AMT_CREDIT_SUM", "AMT_CREDIT_SUM_DEBT", "AMT_CREDIT_SUM_LIMIT", "AMT_CREDIT_SUM_OVERDUE", "DAYS_CREDIT_UPDATE", "0", "1", "2", "3", "4", "5", "C", "X", "MONTHS_BALANCE", "CNT_INSTALMENT", "CNT_INSTALMENT_FUTURE", "SK_DPD", "SK_DPD_DEF", "AMT_APPLICATION", "AMT_DOWN_PAYMENT", "NFLAG_LAST_APPL_IN_DAY", "RATE_DOWN_PAYMENT", "RATE_INTEREST_PRIMARY", "RATE_INTEREST_PRIVILEGED", "DAYS_DECISION", "SELLERPLACE_AREA", "CNT_PAYMENT", "DAYS_FIRST_DRAWING", "DAYS_FIRST_DUE", "DAYS_LAST_DUE_1ST_VERSION", "DAYS_LAST_DUE", "DAYS_TERMINATION", "NFLAG_INSURED_ON_APPROVAL", "NUM_INSTALMENT_VERSION", "NUM_INSTALMENT_NUMBER", "DAYS_INSTALMENT", "DAYS_ENTRY_PAYMENT", "AMT_INSTALMENT", "AMT_PAYMENT", "AMT_BALANCE", "AMT_CREDIT_LIMIT_ACTUAL", "AMT_DRAWINGS_ATM_CURRENT", "AMT_DRAWINGS_CURRENT", "AMT_DRAWINGS_OTHER_CURRENT", "AMT_DRAWINGS_POS_CURRENT", "AMT_INST_MIN_REGULARITY", "AMT_PAYMENT_CURRENT", "AMT_PAYMENT_TOTAL_CURRENT", "AMT_RECEIVABLE_PRINCIPAL", "AMT_RECIVABLE", "AMT_TOTAL_RECEIVABLE", "CNT_DRAWINGS_ATM_CURRENT", "CNT_DRAWINGS_CURRENT", "CNT_DRAWINGS_OTHER_CURRENT", "CNT_DRAWINGS_POS_CURRENT", "CNT_INSTALMENT_MATURE_CUM", "TERM", "OVER_EXPECT_CREDIT", "MEAN_BUILDING_SCORE_AVG", "TOTAL_BUILDING_SCORE_AVG", "FLAG_DOCUMENT_TOTAL", "AMT_REQ_CREDIT_BUREAU_TOTAL", "BIRTH_EMPLOYED_INTERVEL", "BIRTH_REGISTRATION_INTERVEL", "INCOME_PER_FAMILY_MEMBER", "SEASON_REMAINING", "RATIO_INCOME_GOODS", "CHILDREN_RATIO"], "features": {"1": {"effect": -0.01979289675194492, "value": 1.3867440895475052}, "2": {"effect": 0.041958871937796724, "value": 1.393497355554998}, "5": {"effect": -0.015392024549569233, "value": -0.24017445822638622}, "7": {"effect": 0.008174621057976204, "value": -1.4422635595461717}, "8": {"effect": -0.009511757461435965, "value": 0.6241687400298379}, "9": {"effect": 0.017062622147390315, "value": 1.3067495156879596}, "10": {"effect": -0.0009842111009796756, "value": 2.8603741696472498}, "11": {"effect": 0.006550843121837638, "value": 0.7569853472987765}, "12": {"effect": -0.003670741674460836, "value": 0.8353933064250906}, "13": {"effect": -0.014512398506867566, "val ...

# %% [markdown]
# ##### TreeExplainer

# %%
tree_explainer = shap.TreeExplainer(model_opti)

# %%
shap_values_tree = tree_explainer.shap_values(X_train2_sc_pd)

# %%
shap_values_tree = pd.read_pickle("shap_values_tree.pickle")

# %%
tree_explainer.expected_value
# Out:
# [-0.584712638140194, 0.584712638140194]

# %%
shap.summary_plot(shap_values_tree, feature_names=X_train2_sc_pd.columns)

# %%
shap.force_plot(tree_explainer.expected_value[0], shap_values_tree[0][0,:], X_train2_sc_pd.iloc[0,:])
# Out:
# <div id='iOMORXV95B0V64RRN4PN7'>
# <div style='color: #900; text-align: center;'>
#   <b>Visualization omitted, Javascript library not loaded!</b><br>
#   Have you run `initjs()` in this notebook? If this notebook was from another
#   user you must also trust this notebook (File -> Trust notebook). If you are viewing
#   this notebook on github the Javascript has been stripped for security. If you are using
#   JupyterLab this error is because a JupyterLab extension has not yet been written.
# </div></div>
#  <script>
#    if (window.SHAP) SHAP.ReactDom.render(
#     SHAP.React.createElement(SHAP.AdditiveForceVisualizer, {"outNames": ["f(x)"], "baseValue": -0.584712638140194, "outValue": 2.9541014951259994, "link": "identity", "featureNames": ["NAME_CONTRACT_TYPE", "CODE_GENDER", "FLAG_OWN_CAR", "FLAG_OWN_REALTY", "AMT_INCOME_TOTAL", "AMT_GOODS_PRICE", "NAME_TYPE_SUITE", "NAME_INCOME_TYPE", "NAME_EDUCATION_TYPE", "NAME_FAMILY_STATUS", "NAME_HOUSING_TYPE", "REGION_POPULATION_RELATIVE", "DAYS_ID_PUBLISH", "OWN_CAR_AGE", "FLAG_MOBIL", "FLAG_EMP_PHONE", "FLAG_WORK_PHONE", "FLAG_CONT_MOBILE", "FLAG_PHONE", "FLAG_EMAIL", "OCCUPATION_TYPE", "REGION_RATING_CLIENT", "REGION_RATING_CLIENT_W_CITY", "WEEKDAY_APPR_PROCESS_START", "HOUR_APPR_PROCESS_START", "REG_REGION_NOT_LIVE_REGION", "REG_REGION_NOT_WORK_REGION", "LIVE_REGION_NOT_WORK_REGION", "REG_CITY_NOT_LIVE_CITY", "REG_CITY_NOT_WORK_CITY", "LIVE_CITY_NOT_WORK_CITY", "ORGANIZATION_TYPE", "EXT_SOURCE_1", "EXT_SOURCE_2", "EXT_SOURCE_3", "APARTMENTS_MODE", "BASEMENTAREA_MODE", "YEARS_BEGINEXPLUATATION_MODE", "YEARS_BUILD_MODE", "COMMONAREA_MODE", "ELEVATORS_MODE", "ENTRANCES_MODE", "FLOORSMAX_MODE", "FLOORSMIN_MODE", "LANDAREA_MODE", "LIVINGAPARTMENTS_MODE", "LIVINGAREA_MODE", "NONLIVINGAPARTMENTS_MODE", "NONLIVINGAREA_MODE", "APARTMENTS_MEDI", "BASEMENTAREA_MEDI", "YEARS_BEGINEXPLUATATION_MEDI", "YEARS_BUILD_MEDI", "COMMONAREA_MEDI", "ELEVATORS_MEDI", "ENTRANCES_MEDI", "FLOORSMAX_MEDI", "FLOORSMIN_MEDI", "LANDAREA_MEDI", "LIVINGAPARTMENTS_MEDI", "LIVINGAREA_MEDI", "NONLIVINGAPARTMENTS_MEDI", "NONLIVINGAREA_MEDI", "FONDKAPREMONT_MODE", "HOUSETYPE_MODE", "TOTALAREA_MODE", "WALLSMATERIAL_MODE", "EMERGENCYSTATE_MODE", "OBS_30_CNT_SOCIAL_CIRCLE", "DEF_30_CNT_SOCIAL_CIRCLE", "OBS_60_CNT_SOCIAL_CIRCLE", "DEF_60_CNT_SOCIAL_CIRCLE", "DAYS_LAST_PHONE_CHANGE", "SK_ID_BUREAU", "DAYS_CREDIT", "CREDIT_DAY_OVERDUE", "DAYS_CREDIT_ENDDATE", "DAYS_ENDDATE_FACT", "AMT_CREDIT_MAX_OVERDUE", "CNT_CREDIT_PROLONG", "AMT_CREDIT_SUM", "AMT_CREDIT_SUM_DEBT", "AMT_CREDIT_SUM_LIMIT", "AMT_CREDIT_SUM_OVERDUE", "DAYS_CREDIT_UPDATE", "0", "1", "2", "3", "4", "5", "C", "X", "MONTHS_BALANCE", "CNT_INSTALMENT", "CNT_INSTALMENT_FUTURE", "SK_DPD", "SK_DPD_DEF", "AMT_APPLICATION", "AMT_DOWN_PAYMENT", "NFLAG_LAST_APPL_IN_DAY", "RATE_DOWN_PAYMENT", "RATE_INTEREST_PRIMARY", "RATE_INTEREST_PRIVILEGED", "DAYS_DECISION", "SELLERPLACE_AREA", "CNT_PAYMENT", "DAYS_FIRST_DRAWING", "DAYS_FIRST_DUE", "DAYS_LAST_DUE_1ST_VERSION", "DAYS_LAST_DUE", "DAYS_TERMINATION", "NFLAG_INSURED_ON_APPROVAL", "NUM_INSTALMENT_VERSION", "NUM_INSTALMENT_NUMBER", "DAYS_INSTALMENT", "DAYS_ENTRY_PAYMENT", "AMT_INSTALMENT", "AMT_PAYMENT", "AMT_BALANCE", "AMT_CREDIT_LIMIT_ACTUAL", "AMT_DRAWINGS_ATM_CURRENT", "AMT_DRAWINGS_CURRENT", "AMT_DRAWINGS_OTHER_CURRENT", "AMT_DRAWINGS_POS_CURRENT", "AMT_INST_MIN_REGULARITY", "AMT_PAYMENT_CURRENT", "AMT_PAYMENT_TOTAL_CURRENT", "AMT_RECEIVABLE_PRINCIPAL", "AMT_RECIVABLE", "AMT_TOTAL_RECEIVABLE", "CNT_DRAWINGS_ATM_CURRENT", "CNT_DRAWINGS_CURRENT", "CNT_DRAWINGS_OTHER_CURRENT", "CNT_DRAWINGS_POS_CURRENT", "CNT_INSTALMENT_MATURE_CUM", "TERM", "OVER_EXPECT_CREDIT", "MEAN_BUILDING_SCORE_AVG", "TOTAL_BUILDING_SCORE_AVG", "FLAG_DOCUMENT_TOTAL", "AMT_REQ_CREDIT_BUREAU_TOTAL", "BIRTH_EMPLOYED_INTERVEL", "BIRTH_REGISTRATION_INTERVEL", "INCOME_PER_FAMILY_MEMBER", "SEASON_REMAINING", "RATIO_INCOME_GOODS", "CHILDREN_RATIO"], "features": {"0": {"effect": 7.956463928923146e-05, "value": -0.3251536962099354}, "1": {"effect": 0.18972586992194848, "value": -0.7210540497246832}, "2": {"effect": 0.24861281289709672, "value": 1.393497355554998}, "3": {"effect": 0.02990854830741991, "value": 0.6638480156505466}, "4": {"effect": 0.03702336637970378, "value": 0.3679771386345423}, "5": {"effect": 0.014936969011271825, "value": 0.9777239521993364}, "6": {"effect": 0.016258987612708813, "value": 0.4377782320433843}, "7": {"effect": 0.045434701797746974, "value": -1.4422635595461717}, "8": {"effect": -0.02510409085389632, "value": 0.6241687400298379}, "9": {"effect": 0.24268052038166274, "value": -0.404299 ...

# %%
for i in range(3):
    shap.bar_plot(shap_values_tree[0][i], feature_names=X_train2_sc_pd.columns)

# %%
for i in range(5):
    shap.plots._waterfall.waterfall_legacy(tree_explainer.expected_value[0], shap_values_tree[0][i], feature_names = X_train2_sc_pd.columns, max_display = 15)

# %% [markdown]
# ## ready to API

# %%
main_features = ['EXT_SOURCE_1',
'EXT_SOURCE_2',
'EXT_SOURCE_3',
'CODE_GENDER',
'NAME_FAMILY_STATUS',
'AMT_REQ_CREDIT_BUREAU_TOTAL',
'BIRTH_EMPLOYED_INTERVEL',
'AMT_INCOME_TOTAL',
'AMT_GOODS_PRICE',
'AMT_CREDIT_SUM_DEBT'
]

# %%
for i in main_features:
    nm.analyse_univariee(X_train2[i])
# Out:
# <style type="text/css">
# #T_28049_row0_col0, #T_28049_row0_col1, #T_28049_row0_col2, #T_28049_row0_col3, #T_28049_row0_col4, #T_28049_row0_col5, #T_28049_row0_col6, #T_28049_row0_col7, #T_28049_row0_col8, #T_28049_row0_col9, #T_28049_row0_col10, #T_28049_row0_col11 {
#   text-align: right;
# }
# </style>
# <table id="T_28049_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Null</th>
#       <th class="col_heading level0 col1" >Not Null</th>
#       <th class="col_heading level0 col2" >Min</th>
#       <th class="col_heading level0 col3" >Q1</th>
#       <th class="col_heading level0 col4" >Med</th>
#       <th class="col_heading level0 col5" >Mean</th>
#       <th class="col_heading level0 col6" >Q3</th>
#       <th class="col_heading level0 col7" >Max</th>
#       <th class="col_heading level0 col8" >Var</th>
#       <th class="col_heading level0 col9" >Std</th>
#       <th class="col_heading level0 col10" >Skew</th>
#       <th class="col_heading level0 col11" >Kurt</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_28049_level0_row0" class="row_heading level0 row0" >EXT_SOURCE_1</th>
#       <td id="T_28049_row0_col0" class="data row0 col0" >0</td>
#       <td id="T_28049_row0_col1" class="data row0 col1" >215257</td>
#       <td id="T_28049_row0_col2" class="data row0 col2" >0.014568</td>
#       <td id="T_28049_row0_col3" class="data row0 col3" >0.505998</td>
#       <td id="T_28049_row0_col4" class="data row0 col4" >0.505998</td>
#       <td id="T_28049_row0_col5" class="data row0 col5" >0.504076</td>
#       <td id="T_28049_row0_col6" class="data row0 col6" >0.505998</td>
#       <td id="T_28049_row0_col7" class="data row0 col7" >0.951624</td>
#       <td id="T_28049_row0_col8" class="data row0 col8" >0.019478</td>
#       <td id="T_28049_row0_col9" class="data row0 col9" >0.139562</td>
#       <td id="T_28049_row0_col10" class="data row0 col10" >-0.153734</td>
#       <td id="T_28049_row0_col11" class="data row0 col11" >1.675467</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# #T_31f41_row0_col0, #T_31f41_row0_col1, #T_31f41_row0_col2, #T_31f41_row0_col3, #T_31f41_row0_col4, #T_31f41_row0_col5, #T_31f41_row0_col6, #T_31f41_row0_col7, #T_31f41_row0_col8, #T_31f41_row0_col9, #T_31f41_row0_col10, #T_31f41_row0_col11 {
#   text-align: right;
# }
# </style>
# <table id="T_31f41_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Null</th>
#       <th class="col_heading level0 col1" >Not Null</th>
#       <th class="col_heading level0 col2" >Min</th>
#       <th class="col_heading level0 col3" >Q1</th>
#       <th class="col_heading level0 col4" >Med</th>
#       <th class="col_heading level0 col5" >Mean</th>
#       <th class="col_heading level0 col6" >Q3</th>
#       <th class="col_heading level0 col7" >Max</th>
#       <th class="col_heading level0 col8" >Var</th>
#       <th class="col_heading level0 col9" >Std</th>
#       <th class="col_heading level0 col10" >Skew</th>
#       <th class="col_heading level0 col11" >Kurt</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_31f41_level0_row0" class="row_heading level0 row0" >EXT_SOURCE_2</th>
#       <td id="T_31f41_row0_col0" class="data row0 col0" >0</td>
#       <td id="T_31f41_row0_col1" class="data row0 col1" >215257</td>
#       <td id="T_31f41_row0_col2" class="data row0 col2" >0.000000</td>
#       <td id="T_31f41_row0_col3" class="data row0 col3" >0.392510</td>
#       <td id="T_31f41_row0_col4" class="data row0 col4" >0.565961</td>
#       <td id="T_31f41_row0_col5" class="data row0 col5" >0.514476</td>
#       <td id="T_31f41_row0_col6" class="data row0 col6" >0.663476</td>
#       <td id="T_31f41_row0_col7" class="data row0 col7" >0.855000</td>
#       <td id="T_31f41_row0_col8" class="data row0 col8" >0.036435</td>
#       <td id="T_31f41_row0_col9" class="data row0 col9" >0.190879</td>
#       <td id="T_31f41_row0_col10" class="data row0 col10" >-0.795285</td>
#       <td id="T_31f41_row0_col11" class="data row0 col11" >-0.261665</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# #T_24bc5_row0_col0, #T_24bc5_row0_col1, #T_24bc5_row0_col2, #T_24bc5_row0_col3, #T_24bc5_row0_col4, #T_24bc5_row0_col5, #T_24bc5_row0_col6, #T_24bc5_row0_col7, #T_24bc5_row0_col8, #T_24bc5_row0_col9, #T_24bc5_row0_col10, #T_24bc5_row0_col11 {
#   text-align: right;
# }
# </style>
# <table id="T_24bc5_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Null</th>
#       <th class="col_heading level0 col1" >Not Null</th>
#       <th class="col_heading level0 col2" >Min</th>
#       <th class="col_heading level0 col3" >Q1</th>
#       <th class="col_heading level0 col4" >Med</th>
#       <th class="col_heading level0 col5" >Mean</th>
#       <th class="col_heading level0 col6" >Q3</th>
#       <th class="col_heading level0 col7" >Max</th>
#       <th class="col_heading level0 col8" >Var</th>
#       <th class="col_heading level0 col9" >Std</th>
#       <th class="col_heading level0 col10" >Skew</th>
#       <th class="col_heading level0 col11" >Kurt</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_24bc5_level0_row0" class="row_heading level0 row0" >EXT_SOURCE_3</th>
#       <td id="T_24bc5_row0_col0" class="data row0 col0" >0</td>
#       <td id="T_24bc5_row0_col1" class="data row0 col1" >215257</td>
#       <td id="T_24bc5_row0_col2" class="data row0 col2" >0.000527</td>
#       <td id="T_24bc5_row0_col3" class="data row0 col3" >0.417100</td>
#       <td id="T_24bc5_row0_col4" class="data row0 col4" >0.535276</td>
#       <td id="T_24bc5_row0_col5" class="data row0 col5" >0.515696</td>
#       <td id="T_24bc5_row0_col6" class="data row0 col6" >0.636376</td>
#       <td id="T_24bc5_row0_col7" class="data row0 col7" >0.896010</td>
#       <td id="T_24bc5_row0_col8" class="data row0 col8" >0.030517</td>
#       <td id="T_24bc5_row0_col9" class="data row0 col9" >0.174690</td>
#       <td id="T_24bc5_row0_col10" class="data row0 col10" >-0.539981</td>
#       <td id="T_24bc5_row0_col11" class="data row0 col11" >-0.037101</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# </style>
# <table id="T_21999_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Null</th>
#       <th class="col_heading level0 col1" >Not Null</th>
#       <th class="col_heading level0 col2" >Min</th>
#       <th class="col_heading level0 col3" >Q1</th>
#       <th class="col_heading level0 col4" >Med</th>
#       <th class="col_heading level0 col5" >Mean</th>
#       <th class="col_heading level0 col6" >Q3</th>
#       <th class="col_heading level0 col7" >Max</th>
#       <th class="col_heading level0 col8" >Var</th>
#       <th class="col_heading level0 col9" >Std</th>
#       <th class="col_heading level0 col10" >Skew</th>
#       <th class="col_heading level0 col11" >Kurt</th>
#     </tr>
#   </thead>
#   <tbody>
#   </tbody>
# </table>
# <style type="text/css">
# </style>
# <table id="T_3b116_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Null</th>
#       <th class="col_heading level0 col1" >Not Null</th>
#       <th class="col_heading level0 col2" >Min</th>
#       <th class="col_heading level0 col3" >Q1</th>
#       <th class="col_heading level0 col4" >Med</th>
#       <th class="col_heading level0 col5" >Mean</th>
#       <th class="col_heading level0 col6" >Q3</th>
#       <th class="col_heading level0 col7" >Max</th>
#       <th class="col_heading level0 col8" >Var</th>
#       <th class="col_heading level0 col9" >Std</th>
#       <th class="col_heading level0 col10" >Skew</th>
#       <th class="col_heading level0 col11" >Kurt</th>
#     </tr>
#   </thead>
#   <tbody>
#   </tbody>
# </table>
# <style type="text/css">
# #T_3c58b_row0_col0, #T_3c58b_row0_col1, #T_3c58b_row0_col2, #T_3c58b_row0_col3, #T_3c58b_row0_col4, #T_3c58b_row0_col5, #T_3c58b_row0_col6, #T_3c58b_row0_col7, #T_3c58b_row0_col8, #T_3c58b_row0_col9, #T_3c58b_row0_col10, #T_3c58b_row0_col11 {
#   text-align: right;
# }
# </style>
# <table id="T_3c58b_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Null</th>
#       <th class="col_heading level0 col1" >Not Null</th>
#       <th class="col_heading level0 col2" >Min</th>
#       <th class="col_heading level0 col3" >Q1</th>
#       <th class="col_heading level0 col4" >Med</th>
#       <th class="col_heading level0 col5" >Mean</th>
#       <th class="col_heading level0 col6" >Q3</th>
#       <th class="col_heading level0 col7" >Max</th>
#       <th class="col_heading level0 col8" >Var</th>
#       <th class="col_heading level0 col9" >Std</th>
#       <th class="col_heading level0 col10" >Skew</th>
#       <th class="col_heading level0 col11" >Kurt</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_3c58b_level0_row0" class="row_heading level0 row0" >AMT_REQ_CREDIT_BUREAU_TOTAL</th>
#       <td id="T_3c58b_row0_col0" class="data row0 col0" >0</td>
#       <td id="T_3c58b_row0_col1" class="data row0 col1" >215257</td>
#       <td id="T_3c58b_row0_col2" class="data row0 col2" >0.000000</td>
#       <td id="T_3c58b_row0_col3" class="data row0 col3" >0.000000</td>
#       <td id="T_3c58b_row0_col4" class="data row0 col4" >2.000000</td>
#       <td id="T_3c58b_row0_col5" class="data row0 col5" >2.140948</td>
#       <td id="T_3c58b_row0_col6" class="data row0 col6" >3.000000</td>
#       <td id="T_3c58b_row0_col7" class="data row0 col7" >30.000000</td>
#       <td id="T_3c58b_row0_col8" class="data row0 col8" >5.022339</td>
#       <td id="T_3c58b_row0_col9" class="data row0 col9" >2.241058</td>
#       <td id="T_3c58b_row0_col10" class="data row0 col10" >1.473564</td>
#       <td id="T_3c58b_row0_col11" class="data row0 col11" >3.695851</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# #T_5b7c8_row0_col0, #T_5b7c8_row0_col1, #T_5b7c8_row0_col2, #T_5b7c8_row0_col3, #T_5b7c8_row0_col4, #T_5b7c8_row0_col5, #T_5b7c8_row0_col6, #T_5b7c8_row0_col7, #T_5b7c8_row0_col8, #T_5b7c8_row0_col9, #T_5b7c8_row0_col10, #T_5b7c8_row0_col11 {
#   text-align: right;
# }
# </style>
# <table id="T_5b7c8_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Null</th>
#       <th class="col_heading level0 col1" >Not Null</th>
#       <th class="col_heading level0 col2" >Min</th>
#       <th class="col_heading level0 col3" >Q1</th>
#       <th class="col_heading level0 col4" >Med</th>
#       <th class="col_heading level0 col5" >Mean</th>
#       <th class="col_heading level0 col6" >Q3</th>
#       <th class="col_heading level0 col7" >Max</th>
#       <th class="col_heading level0 col8" >Var</th>
#       <th class="col_heading level0 col9" >Std</th>
#       <th class="col_heading level0 col10" >Skew</th>
#       <th class="col_heading level0 col11" >Kurt</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_5b7c8_level0_row0" class="row_heading level0 row0" >BIRTH_EMPLOYED_INTERVEL</th>
#       <td id="T_5b7c8_row0_col0" class="data row0 col0" >0</td>
#       <td id="T_5b7c8_row0_col1" class="data row0 col1" >215257</td>
#       <td id="T_5b7c8_row0_col2" class="data row0 col2" >6544.000000</td>
#       <td id="T_5b7c8_row0_col3" class="data row0 col3" >9940.000000</td>
#       <td id="T_5b7c8_row0_col4" class="data row0 col4" >13171.000000</td>
#       <td id="T_5b7c8_row0_col5" class="data row0 col5" >79837.920305</td>
#       <td id="T_5b7c8_row0_col6" class="data row0 col6" >17853.000000</td>
#       <td id="T_5b7c8_row0_col7" class="data row0 col7" >390440.000000</td>
#       <td id="T_5b7c8_row0_col8" class="data row0 col8" >20733907181.506718</td>
#       <td id="T_5b7c8_row0_col9" class="data row0 col9" >143992.733086</td>
#       <td id="T_5b7c8_row0_col10" class="data row0 col10" >1.663624</td>
#       <td id="T_5b7c8_row0_col11" class="data row0 col11" >0.771295</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# #T_58f6c_row0_col0, #T_58f6c_row0_col1, #T_58f6c_row0_col2, #T_58f6c_row0_col3, #T_58f6c_row0_col4, #T_58f6c_row0_col5, #T_58f6c_row0_col6, #T_58f6c_row0_col7, #T_58f6c_row0_col8, #T_58f6c_row0_col9, #T_58f6c_row0_col10, #T_58f6c_row0_col11 {
#   text-align: right;
# }
# </style>
# <table id="T_58f6c_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Null</th>
#       <th class="col_heading level0 col1" >Not Null</th>
#       <th class="col_heading level0 col2" >Min</th>
#       <th class="col_heading level0 col3" >Q1</th>
#       <th class="col_heading level0 col4" >Med</th>
#       <th class="col_heading level0 col5" >Mean</th>
#       <th class="col_heading level0 col6" >Q3</th>
#       <th class="col_heading level0 col7" >Max</th>
#       <th class="col_heading level0 col8" >Var</th>
#       <th class="col_heading level0 col9" >Std</th>
#       <th class="col_heading level0 col10" >Skew</th>
#       <th class="col_heading level0 col11" >Kurt</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_58f6c_level0_row0" class="row_heading level0 row0" >AMT_INCOME_TOTAL</th>
#       <td id="T_58f6c_row0_col0" class="data row0 col0" >0</td>
#       <td id="T_58f6c_row0_col1" class="data row0 col1" >215257</td>
#       <td id="T_58f6c_row0_col2" class="data row0 col2" >25650.000000</td>
#       <td id="T_58f6c_row0_col3" class="data row0 col3" >112500.000000</td>
#       <td id="T_58f6c_row0_col4" class="data row0 col4" >148500.000000</td>
#       <td id="T_58f6c_row0_col5" class="data row0 col5" >169084.258002</td>
#       <td id="T_58f6c_row0_col6" class="data row0 col6" >202500.000000</td>
#       <td id="T_58f6c_row0_col7" class="data row0 col7" >117000000.000000</td>
#       <td id="T_58f6c_row0_col8" class="data row0 col8" >75210098847.242325</td>
#       <td id="T_58f6c_row0_col9" class="data row0 col9" >274244.596751</td>
#       <td id="T_58f6c_row0_col10" class="data row0 col10" >360.911898</td>
#       <td id="T_58f6c_row0_col11" class="data row0 col11" >153102.433634</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# #T_437fe_row0_col0, #T_437fe_row0_col1, #T_437fe_row0_col2, #T_437fe_row0_col3, #T_437fe_row0_col4, #T_437fe_row0_col5, #T_437fe_row0_col6, #T_437fe_row0_col7, #T_437fe_row0_col8, #T_437fe_row0_col9, #T_437fe_row0_col10, #T_437fe_row0_col11 {
#   text-align: right;
# }
# </style>
# <table id="T_437fe_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Null</th>
#       <th class="col_heading level0 col1" >Not Null</th>
#       <th class="col_heading level0 col2" >Min</th>
#       <th class="col_heading level0 col3" >Q1</th>
#       <th class="col_heading level0 col4" >Med</th>
#       <th class="col_heading level0 col5" >Mean</th>
#       <th class="col_heading level0 col6" >Q3</th>
#       <th class="col_heading level0 col7" >Max</th>
#       <th class="col_heading level0 col8" >Var</th>
#       <th class="col_heading level0 col9" >Std</th>
#       <th class="col_heading level0 col10" >Skew</th>
#       <th class="col_heading level0 col11" >Kurt</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_437fe_level0_row0" class="row_heading level0 row0" >AMT_GOODS_PRICE</th>
#       <td id="T_437fe_row0_col0" class="data row0 col0" >0</td>
#       <td id="T_437fe_row0_col1" class="data row0 col1" >215257</td>
#       <td id="T_437fe_row0_col2" class="data row0 col2" >40500.000000</td>
#       <td id="T_437fe_row0_col3" class="data row0 col3" >238500.000000</td>
#       <td id="T_437fe_row0_col4" class="data row0 col4" >450000.000000</td>
#       <td id="T_437fe_row0_col5" class="data row0 col5" >538741.807426</td>
#       <td id="T_437fe_row0_col6" class="data row0 col6" >679500.000000</td>
#       <td id="T_437fe_row0_col7" class="data row0 col7" >4050000.000000</td>
#       <td id="T_437fe_row0_col8" class="data row0 col8" >136522081214.284409</td>
#       <td id="T_437fe_row0_col9" class="data row0 col9" >369488.945997</td>
#       <td id="T_437fe_row0_col10" class="data row0 col10" >1.352428</td>
#       <td id="T_437fe_row0_col11" class="data row0 col11" >2.486891</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# #T_bc573_row0_col0, #T_bc573_row0_col1, #T_bc573_row0_col2, #T_bc573_row0_col3, #T_bc573_row0_col4, #T_bc573_row0_col5, #T_bc573_row0_col6, #T_bc573_row0_col7, #T_bc573_row0_col8, #T_bc573_row0_col9, #T_bc573_row0_col10, #T_bc573_row0_col11 {
#   text-align: right;
# }
# </style>
# <table id="T_bc573_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Null</th>
#       <th class="col_heading level0 col1" >Not Null</th>
#       <th class="col_heading level0 col2" >Min</th>
#       <th class="col_heading level0 col3" >Q1</th>
#       <th class="col_heading level0 col4" >Med</th>
#       <th class="col_heading level0 col5" >Mean</th>
#       <th class="col_heading level0 col6" >Q3</th>
#       <th class="col_heading level0 col7" >Max</th>
#       <th class="col_heading level0 col8" >Var</th>
#       <th class="col_heading level0 col9" >Std</th>
#       <th class="col_heading level0 col10" >Skew</th>
#       <th class="col_heading level0 col11" >Kurt</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_bc573_level0_row0" class="row_heading level0 row0" >AMT_CREDIT_SUM_DEBT</th>
#       <td id="T_bc573_row0_col0" class="data row0 col0" >0</td>
#       <td id="T_bc573_row0_col1" class="data row0 col1" >215257</td>
#       <td id="T_bc573_row0_col2" class="data row0 col2" >-1083614.670000</td>
#       <td id="T_bc573_row0_col3" class="data row0 col3" >4365.000000</td>
#       <td id="T_bc573_row0_col4" class="data row0 col4" >44208.035000</td>
#       <td id="T_bc573_row0_col5" class="data row0 col5" >141119.165844</td>
#       <td id="T_bc573_row0_col6" class="data row0 col6" >113301.900000</td>
#       <td id="T_bc573_row0_col7" class="data row0 col7" >43650000.000000</td>
#       <td id="T_bc573_row0_col8" class="data row0 col8" >233707676394.214905</td>
#       <td id="T_bc573_row0_col9" class="data row0 col9" >483433.218133</td>
#       <td id="T_bc573_row0_col10" class="data row0 col10" >22.189971</td>
#       <td id="T_bc573_row0_col11" class="data row0 col11" >1100.884224</td>
#     </tr>
#   </tbody>
# </table>

# %%
for i in main_features:
    nm.analyse_univariee(X_train2_sc_pd[i])
# Out:
# <style type="text/css">
# #T_1697d_row0_col0, #T_1697d_row0_col1, #T_1697d_row0_col2, #T_1697d_row0_col3, #T_1697d_row0_col4, #T_1697d_row0_col5, #T_1697d_row0_col6, #T_1697d_row0_col7, #T_1697d_row0_col8, #T_1697d_row0_col9, #T_1697d_row0_col10, #T_1697d_row0_col11 {
#   text-align: right;
# }
# </style>
# <table id="T_1697d_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Null</th>
#       <th class="col_heading level0 col1" >Not Null</th>
#       <th class="col_heading level0 col2" >Min</th>
#       <th class="col_heading level0 col3" >Q1</th>
#       <th class="col_heading level0 col4" >Med</th>
#       <th class="col_heading level0 col5" >Mean</th>
#       <th class="col_heading level0 col6" >Q3</th>
#       <th class="col_heading level0 col7" >Max</th>
#       <th class="col_heading level0 col8" >Var</th>
#       <th class="col_heading level0 col9" >Std</th>
#       <th class="col_heading level0 col10" >Skew</th>
#       <th class="col_heading level0 col11" >Kurt</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_1697d_level0_row0" class="row_heading level0 row0" >EXT_SOURCE_1</th>
#       <td id="T_1697d_row0_col0" class="data row0 col0" >0</td>
#       <td id="T_1697d_row0_col1" class="data row0 col1" >215257</td>
#       <td id="T_1697d_row0_col2" class="data row0 col2" >-3.507449</td>
#       <td id="T_1697d_row0_col3" class="data row0 col3" >0.013770</td>
#       <td id="T_1697d_row0_col4" class="data row0 col4" >0.013770</td>
#       <td id="T_1697d_row0_col5" class="data row0 col5" >-0.000000</td>
#       <td id="T_1697d_row0_col6" class="data row0 col6" >0.013770</td>
#       <td id="T_1697d_row0_col7" class="data row0 col7" >3.206794</td>
#       <td id="T_1697d_row0_col8" class="data row0 col8" >1.000000</td>
#       <td id="T_1697d_row0_col9" class="data row0 col9" >1.000000</td>
#       <td id="T_1697d_row0_col10" class="data row0 col10" >-0.153734</td>
#       <td id="T_1697d_row0_col11" class="data row0 col11" >1.675467</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# #T_0662a_row0_col0, #T_0662a_row0_col1, #T_0662a_row0_col2, #T_0662a_row0_col3, #T_0662a_row0_col4, #T_0662a_row0_col5, #T_0662a_row0_col6, #T_0662a_row0_col7, #T_0662a_row0_col8, #T_0662a_row0_col9, #T_0662a_row0_col10, #T_0662a_row0_col11 {
#   text-align: right;
# }
# </style>
# <table id="T_0662a_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Null</th>
#       <th class="col_heading level0 col1" >Not Null</th>
#       <th class="col_heading level0 col2" >Min</th>
#       <th class="col_heading level0 col3" >Q1</th>
#       <th class="col_heading level0 col4" >Med</th>
#       <th class="col_heading level0 col5" >Mean</th>
#       <th class="col_heading level0 col6" >Q3</th>
#       <th class="col_heading level0 col7" >Max</th>
#       <th class="col_heading level0 col8" >Var</th>
#       <th class="col_heading level0 col9" >Std</th>
#       <th class="col_heading level0 col10" >Skew</th>
#       <th class="col_heading level0 col11" >Kurt</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_0662a_level0_row0" class="row_heading level0 row0" >EXT_SOURCE_2</th>
#       <td id="T_0662a_row0_col0" class="data row0 col0" >0</td>
#       <td id="T_0662a_row0_col1" class="data row0 col1" >215257</td>
#       <td id="T_0662a_row0_col2" class="data row0 col2" >-2.695291</td>
#       <td id="T_0662a_row0_col3" class="data row0 col3" >-0.638969</td>
#       <td id="T_0662a_row0_col4" class="data row0 col4" >0.269730</td>
#       <td id="T_0662a_row0_col5" class="data row0 col5" >0.000000</td>
#       <td id="T_0662a_row0_col6" class="data row0 col6" >0.780597</td>
#       <td id="T_0662a_row0_col7" class="data row0 col7" >1.783975</td>
#       <td id="T_0662a_row0_col8" class="data row0 col8" >1.000000</td>
#       <td id="T_0662a_row0_col9" class="data row0 col9" >1.000000</td>
#       <td id="T_0662a_row0_col10" class="data row0 col10" >-0.795285</td>
#       <td id="T_0662a_row0_col11" class="data row0 col11" >-0.261665</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# #T_a9910_row0_col0, #T_a9910_row0_col1, #T_a9910_row0_col2, #T_a9910_row0_col3, #T_a9910_row0_col4, #T_a9910_row0_col5, #T_a9910_row0_col6, #T_a9910_row0_col7, #T_a9910_row0_col8, #T_a9910_row0_col9, #T_a9910_row0_col10, #T_a9910_row0_col11 {
#   text-align: right;
# }
# </style>
# <table id="T_a9910_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Null</th>
#       <th class="col_heading level0 col1" >Not Null</th>
#       <th class="col_heading level0 col2" >Min</th>
#       <th class="col_heading level0 col3" >Q1</th>
#       <th class="col_heading level0 col4" >Med</th>
#       <th class="col_heading level0 col5" >Mean</th>
#       <th class="col_heading level0 col6" >Q3</th>
#       <th class="col_heading level0 col7" >Max</th>
#       <th class="col_heading level0 col8" >Var</th>
#       <th class="col_heading level0 col9" >Std</th>
#       <th class="col_heading level0 col10" >Skew</th>
#       <th class="col_heading level0 col11" >Kurt</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_a9910_level0_row0" class="row_heading level0 row0" >EXT_SOURCE_3</th>
#       <td id="T_a9910_row0_col0" class="data row0 col0" >0</td>
#       <td id="T_a9910_row0_col1" class="data row0 col1" >215257</td>
#       <td id="T_a9910_row0_col2" class="data row0 col2" >-2.949046</td>
#       <td id="T_a9910_row0_col3" class="data row0 col3" >-0.564408</td>
#       <td id="T_a9910_row0_col4" class="data row0 col4" >0.112085</td>
#       <td id="T_a9910_row0_col5" class="data row0 col5" >0.000000</td>
#       <td id="T_a9910_row0_col6" class="data row0 col6" >0.690824</td>
#       <td id="T_a9910_row0_col7" class="data row0 col7" >2.177076</td>
#       <td id="T_a9910_row0_col8" class="data row0 col8" >1.000000</td>
#       <td id="T_a9910_row0_col9" class="data row0 col9" >1.000000</td>
#       <td id="T_a9910_row0_col10" class="data row0 col10" >-0.539981</td>
#       <td id="T_a9910_row0_col11" class="data row0 col11" >-0.037101</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# #T_5e617_row0_col0, #T_5e617_row0_col1, #T_5e617_row0_col2, #T_5e617_row0_col3, #T_5e617_row0_col4, #T_5e617_row0_col5, #T_5e617_row0_col6, #T_5e617_row0_col7, #T_5e617_row0_col8, #T_5e617_row0_col9, #T_5e617_row0_col10, #T_5e617_row0_col11 {
#   text-align: right;
# }
# </style>
# <table id="T_5e617_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Null</th>
#       <th class="col_heading level0 col1" >Not Null</th>
#       <th class="col_heading level0 col2" >Min</th>
#       <th class="col_heading level0 col3" >Q1</th>
#       <th class="col_heading level0 col4" >Med</th>
#       <th class="col_heading level0 col5" >Mean</th>
#       <th class="col_heading level0 col6" >Q3</th>
#       <th class="col_heading level0 col7" >Max</th>
#       <th class="col_heading level0 col8" >Var</th>
#       <th class="col_heading level0 col9" >Std</th>
#       <th class="col_heading level0 col10" >Skew</th>
#       <th class="col_heading level0 col11" >Kurt</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_5e617_level0_row0" class="row_heading level0 row0" >CODE_GENDER</th>
#       <td id="T_5e617_row0_col0" class="data row0 col0" >0</td>
#       <td id="T_5e617_row0_col1" class="data row0 col1" >215257</td>
#       <td id="T_5e617_row0_col2" class="data row0 col2" >-0.721054</td>
#       <td id="T_5e617_row0_col3" class="data row0 col3" >-0.721054</td>
#       <td id="T_5e617_row0_col4" class="data row0 col4" >-0.721054</td>
#       <td id="T_5e617_row0_col5" class="data row0 col5" >0.000000</td>
#       <td id="T_5e617_row0_col6" class="data row0 col6" >1.386744</td>
#       <td id="T_5e617_row0_col7" class="data row0 col7" >3.494542</td>
#       <td id="T_5e617_row0_col8" class="data row0 col8" >1.000000</td>
#       <td id="T_5e617_row0_col9" class="data row0 col9" >1.000000</td>
#       <td id="T_5e617_row0_col10" class="data row0 col10" >0.665983</td>
#       <td id="T_5e617_row0_col11" class="data row0 col11" >-1.555747</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# #T_a9b24_row0_col0, #T_a9b24_row0_col1, #T_a9b24_row0_col2, #T_a9b24_row0_col3, #T_a9b24_row0_col4, #T_a9b24_row0_col5, #T_a9b24_row0_col6, #T_a9b24_row0_col7, #T_a9b24_row0_col8, #T_a9b24_row0_col9, #T_a9b24_row0_col10, #T_a9b24_row0_col11 {
#   text-align: right;
# }
# </style>
# <table id="T_a9b24_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Null</th>
#       <th class="col_heading level0 col1" >Not Null</th>
#       <th class="col_heading level0 col2" >Min</th>
#       <th class="col_heading level0 col3" >Q1</th>
#       <th class="col_heading level0 col4" >Med</th>
#       <th class="col_heading level0 col5" >Mean</th>
#       <th class="col_heading level0 col6" >Q3</th>
#       <th class="col_heading level0 col7" >Max</th>
#       <th class="col_heading level0 col8" >Var</th>
#       <th class="col_heading level0 col9" >Std</th>
#       <th class="col_heading level0 col10" >Skew</th>
#       <th class="col_heading level0 col11" >Kurt</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_a9b24_level0_row0" class="row_heading level0 row0" >NAME_FAMILY_STATUS</th>
#       <td id="T_a9b24_row0_col0" class="data row0 col0" >0</td>
#       <td id="T_a9b24_row0_col1" class="data row0 col1" >215257</td>
#       <td id="T_a9b24_row0_col2" class="data row0 col2" >-1.259823</td>
#       <td id="T_a9b24_row0_col3" class="data row0 col3" >-0.404299</td>
#       <td id="T_a9b24_row0_col4" class="data row0 col4" >-0.404299</td>
#       <td id="T_a9b24_row0_col5" class="data row0 col5" >0.000000</td>
#       <td id="T_a9b24_row0_col6" class="data row0 col6" >0.451225</td>
#       <td id="T_a9b24_row0_col7" class="data row0 col7" >3.017798</td>
#       <td id="T_a9b24_row0_col8" class="data row0 col8" >1.000000</td>
#       <td id="T_a9b24_row0_col9" class="data row0 col9" >1.000000</td>
#       <td id="T_a9b24_row0_col10" class="data row0 col10" >1.537278</td>
#       <td id="T_a9b24_row0_col11" class="data row0 col11" >2.031818</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# #T_91760_row0_col0, #T_91760_row0_col1, #T_91760_row0_col2, #T_91760_row0_col3, #T_91760_row0_col4, #T_91760_row0_col5, #T_91760_row0_col6, #T_91760_row0_col7, #T_91760_row0_col8, #T_91760_row0_col9, #T_91760_row0_col10, #T_91760_row0_col11 {
#   text-align: right;
# }
# </style>
# <table id="T_91760_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Null</th>
#       <th class="col_heading level0 col1" >Not Null</th>
#       <th class="col_heading level0 col2" >Min</th>
#       <th class="col_heading level0 col3" >Q1</th>
#       <th class="col_heading level0 col4" >Med</th>
#       <th class="col_heading level0 col5" >Mean</th>
#       <th class="col_heading level0 col6" >Q3</th>
#       <th class="col_heading level0 col7" >Max</th>
#       <th class="col_heading level0 col8" >Var</th>
#       <th class="col_heading level0 col9" >Std</th>
#       <th class="col_heading level0 col10" >Skew</th>
#       <th class="col_heading level0 col11" >Kurt</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_91760_level0_row0" class="row_heading level0 row0" >AMT_REQ_CREDIT_BUREAU_TOTAL</th>
#       <td id="T_91760_row0_col0" class="data row0 col0" >0</td>
#       <td id="T_91760_row0_col1" class="data row0 col1" >215257</td>
#       <td id="T_91760_row0_col2" class="data row0 col2" >-0.955329</td>
#       <td id="T_91760_row0_col3" class="data row0 col3" >-0.955329</td>
#       <td id="T_91760_row0_col4" class="data row0 col4" >-0.062893</td>
#       <td id="T_91760_row0_col5" class="data row0 col5" >-0.000000</td>
#       <td id="T_91760_row0_col6" class="data row0 col6" >0.383324</td>
#       <td id="T_91760_row0_col7" class="data row0 col7" >12.431208</td>
#       <td id="T_91760_row0_col8" class="data row0 col8" >1.000000</td>
#       <td id="T_91760_row0_col9" class="data row0 col9" >1.000000</td>
#       <td id="T_91760_row0_col10" class="data row0 col10" >1.473564</td>
#       <td id="T_91760_row0_col11" class="data row0 col11" >3.695851</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# #T_1c9d1_row0_col0, #T_1c9d1_row0_col1, #T_1c9d1_row0_col2, #T_1c9d1_row0_col3, #T_1c9d1_row0_col4, #T_1c9d1_row0_col5, #T_1c9d1_row0_col6, #T_1c9d1_row0_col7, #T_1c9d1_row0_col8, #T_1c9d1_row0_col9, #T_1c9d1_row0_col10, #T_1c9d1_row0_col11 {
#   text-align: right;
# }
# </style>
# <table id="T_1c9d1_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Null</th>
#       <th class="col_heading level0 col1" >Not Null</th>
#       <th class="col_heading level0 col2" >Min</th>
#       <th class="col_heading level0 col3" >Q1</th>
#       <th class="col_heading level0 col4" >Med</th>
#       <th class="col_heading level0 col5" >Mean</th>
#       <th class="col_heading level0 col6" >Q3</th>
#       <th class="col_heading level0 col7" >Max</th>
#       <th class="col_heading level0 col8" >Var</th>
#       <th class="col_heading level0 col9" >Std</th>
#       <th class="col_heading level0 col10" >Skew</th>
#       <th class="col_heading level0 col11" >Kurt</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_1c9d1_level0_row0" class="row_heading level0 row0" >BIRTH_EMPLOYED_INTERVEL</th>
#       <td id="T_1c9d1_row0_col0" class="data row0 col0" >0</td>
#       <td id="T_1c9d1_row0_col1" class="data row0 col1" >215257</td>
#       <td id="T_1c9d1_row0_col2" class="data row0 col2" >-0.509011</td>
#       <td id="T_1c9d1_row0_col3" class="data row0 col3" >-0.485427</td>
#       <td id="T_1c9d1_row0_col4" class="data row0 col4" >-0.462988</td>
#       <td id="T_1c9d1_row0_col5" class="data row0 col5" >0.000000</td>
#       <td id="T_1c9d1_row0_col6" class="data row0 col6" >-0.430473</td>
#       <td id="T_1c9d1_row0_col7" class="data row0 col7" >2.157068</td>
#       <td id="T_1c9d1_row0_col8" class="data row0 col8" >1.000000</td>
#       <td id="T_1c9d1_row0_col9" class="data row0 col9" >1.000000</td>
#       <td id="T_1c9d1_row0_col10" class="data row0 col10" >1.663624</td>
#       <td id="T_1c9d1_row0_col11" class="data row0 col11" >0.771295</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# #T_34d57_row0_col0, #T_34d57_row0_col1, #T_34d57_row0_col2, #T_34d57_row0_col3, #T_34d57_row0_col4, #T_34d57_row0_col5, #T_34d57_row0_col6, #T_34d57_row0_col7, #T_34d57_row0_col8, #T_34d57_row0_col9, #T_34d57_row0_col10, #T_34d57_row0_col11 {
#   text-align: right;
# }
# </style>
# <table id="T_34d57_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Null</th>
#       <th class="col_heading level0 col1" >Not Null</th>
#       <th class="col_heading level0 col2" >Min</th>
#       <th class="col_heading level0 col3" >Q1</th>
#       <th class="col_heading level0 col4" >Med</th>
#       <th class="col_heading level0 col5" >Mean</th>
#       <th class="col_heading level0 col6" >Q3</th>
#       <th class="col_heading level0 col7" >Max</th>
#       <th class="col_heading level0 col8" >Var</th>
#       <th class="col_heading level0 col9" >Std</th>
#       <th class="col_heading level0 col10" >Skew</th>
#       <th class="col_heading level0 col11" >Kurt</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_34d57_level0_row0" class="row_heading level0 row0" >AMT_INCOME_TOTAL</th>
#       <td id="T_34d57_row0_col0" class="data row0 col0" >0</td>
#       <td id="T_34d57_row0_col1" class="data row0 col1" >215257</td>
#       <td id="T_34d57_row0_col2" class="data row0 col2" >-0.523016</td>
#       <td id="T_34d57_row0_col3" class="data row0 col3" >-0.206328</td>
#       <td id="T_34d57_row0_col4" class="data row0 col4" >-0.075058</td>
#       <td id="T_34d57_row0_col5" class="data row0 col5" >0.000000</td>
#       <td id="T_34d57_row0_col6" class="data row0 col6" >0.121846</td>
#       <td id="T_34d57_row0_col7" class="data row0 col7" >426.009909</td>
#       <td id="T_34d57_row0_col8" class="data row0 col8" >1.000000</td>
#       <td id="T_34d57_row0_col9" class="data row0 col9" >1.000000</td>
#       <td id="T_34d57_row0_col10" class="data row0 col10" >360.911898</td>
#       <td id="T_34d57_row0_col11" class="data row0 col11" >153102.433634</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# #T_92732_row0_col0, #T_92732_row0_col1, #T_92732_row0_col2, #T_92732_row0_col3, #T_92732_row0_col4, #T_92732_row0_col5, #T_92732_row0_col6, #T_92732_row0_col7, #T_92732_row0_col8, #T_92732_row0_col9, #T_92732_row0_col10, #T_92732_row0_col11 {
#   text-align: right;
# }
# </style>
# <table id="T_92732_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Null</th>
#       <th class="col_heading level0 col1" >Not Null</th>
#       <th class="col_heading level0 col2" >Min</th>
#       <th class="col_heading level0 col3" >Q1</th>
#       <th class="col_heading level0 col4" >Med</th>
#       <th class="col_heading level0 col5" >Mean</th>
#       <th class="col_heading level0 col6" >Q3</th>
#       <th class="col_heading level0 col7" >Max</th>
#       <th class="col_heading level0 col8" >Var</th>
#       <th class="col_heading level0 col9" >Std</th>
#       <th class="col_heading level0 col10" >Skew</th>
#       <th class="col_heading level0 col11" >Kurt</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_92732_level0_row0" class="row_heading level0 row0" >AMT_GOODS_PRICE</th>
#       <td id="T_92732_row0_col0" class="data row0 col0" >0</td>
#       <td id="T_92732_row0_col1" class="data row0 col1" >215257</td>
#       <td id="T_92732_row0_col2" class="data row0 col2" >-1.348462</td>
#       <td id="T_92732_row0_col3" class="data row0 col3" >-0.812587</td>
#       <td id="T_92732_row0_col4" class="data row0 col4" >-0.240174</td>
#       <td id="T_92732_row0_col5" class="data row0 col5" >0.000000</td>
#       <td id="T_92732_row0_col6" class="data row0 col6" >0.380954</td>
#       <td id="T_92732_row0_col7" class="data row0 col7" >9.503013</td>
#       <td id="T_92732_row0_col8" class="data row0 col8" >1.000000</td>
#       <td id="T_92732_row0_col9" class="data row0 col9" >1.000000</td>
#       <td id="T_92732_row0_col10" class="data row0 col10" >1.352428</td>
#       <td id="T_92732_row0_col11" class="data row0 col11" >2.486891</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# #T_6fa4b_row0_col0, #T_6fa4b_row0_col1, #T_6fa4b_row0_col2, #T_6fa4b_row0_col3, #T_6fa4b_row0_col4, #T_6fa4b_row0_col5, #T_6fa4b_row0_col6, #T_6fa4b_row0_col7, #T_6fa4b_row0_col8, #T_6fa4b_row0_col9, #T_6fa4b_row0_col10, #T_6fa4b_row0_col11 {
#   text-align: right;
# }
# </style>
# <table id="T_6fa4b_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Null</th>
#       <th class="col_heading level0 col1" >Not Null</th>
#       <th class="col_heading level0 col2" >Min</th>
#       <th class="col_heading level0 col3" >Q1</th>
#       <th class="col_heading level0 col4" >Med</th>
#       <th class="col_heading level0 col5" >Mean</th>
#       <th class="col_heading level0 col6" >Q3</th>
#       <th class="col_heading level0 col7" >Max</th>
#       <th class="col_heading level0 col8" >Var</th>
#       <th class="col_heading level0 col9" >Std</th>
#       <th class="col_heading level0 col10" >Skew</th>
#       <th class="col_heading level0 col11" >Kurt</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_6fa4b_level0_row0" class="row_heading level0 row0" >AMT_CREDIT_SUM_DEBT</th>
#       <td id="T_6fa4b_row0_col0" class="data row0 col0" >0</td>
#       <td id="T_6fa4b_row0_col1" class="data row0 col1" >215257</td>
#       <td id="T_6fa4b_row0_col2" class="data row0 col2" >-2.533409</td>
#       <td id="T_6fa4b_row0_col3" class="data row0 col3" >-0.282881</td>
#       <td id="T_6fa4b_row0_col4" class="data row0 col4" >-0.200464</td>
#       <td id="T_6fa4b_row0_col5" class="data row0 col5" >-0.000000</td>
#       <td id="T_6fa4b_row0_col6" class="data row0 col6" >-0.057541</td>
#       <td id="T_6fa4b_row0_col7" class="data row0 col7" >89.999775</td>
#       <td id="T_6fa4b_row0_col8" class="data row0 col8" >1.000000</td>
#       <td id="T_6fa4b_row0_col9" class="data row0 col9" >1.000000</td>
#       <td id="T_6fa4b_row0_col10" class="data row0 col10" >22.189971</td>
#       <td id="T_6fa4b_row0_col11" class="data row0 col11" >1100.884224</td>
#     </tr>
#   </tbody>
# </table>

# %%
X_train2_sc_pd.sample(20).to_pickle("X_train2_sc_pd_sample.pickle")

# %%
X_train2_sc_pd.mean().round(2).to_pickle("X_train2_sc_pd_mean.pickle")

# %%
X_train2_sc_pd_mean = X_train2_sc_pd.mean().round(2)
X_train2_sc_pd_mean["CODE_GENDER"]
# Out:
# 0.08

# %%
main_features_pd = nm.analyse_univariee(X_train2_sc_pd[main_features[0]])
for i in main_features[1:]:
    main_features_pd = main_features_pd.append(nm.analyse_univariee(X_train2_sc_pd[i]))
main_features_pd
# Out:
# <style type="text/css">
# #T_3202d_row0_col0, #T_3202d_row0_col1, #T_3202d_row0_col2, #T_3202d_row0_col3, #T_3202d_row0_col4, #T_3202d_row0_col5, #T_3202d_row0_col6, #T_3202d_row0_col7, #T_3202d_row0_col8, #T_3202d_row0_col9, #T_3202d_row0_col10, #T_3202d_row0_col11 {
#   text-align: right;
# }
# </style>
# <table id="T_3202d_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Null</th>
#       <th class="col_heading level0 col1" >Not Null</th>
#       <th class="col_heading level0 col2" >Min</th>
#       <th class="col_heading level0 col3" >Q1</th>
#       <th class="col_heading level0 col4" >Med</th>
#       <th class="col_heading level0 col5" >Mean</th>
#       <th class="col_heading level0 col6" >Q3</th>
#       <th class="col_heading level0 col7" >Max</th>
#       <th class="col_heading level0 col8" >Var</th>
#       <th class="col_heading level0 col9" >Std</th>
#       <th class="col_heading level0 col10" >Skew</th>
#       <th class="col_heading level0 col11" >Kurt</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_3202d_level0_row0" class="row_heading level0 row0" >EXT_SOURCE_1</th>
#       <td id="T_3202d_row0_col0" class="data row0 col0" >0</td>
#       <td id="T_3202d_row0_col1" class="data row0 col1" >197880</td>
#       <td id="T_3202d_row0_col2" class="data row0 col2" >-3.506565</td>
#       <td id="T_3202d_row0_col3" class="data row0 col3" >-0.221864</td>
#       <td id="T_3202d_row0_col4" class="data row0 col4" >0.013770</td>
#       <td id="T_3202d_row0_col5" class="data row0 col5" >-0.140326</td>
#       <td id="T_3202d_row0_col6" class="data row0 col6" >0.013770</td>
#       <td id="T_3202d_row0_col7" class="data row0 col7" >3.206794</td>
#       <td id="T_3202d_row0_col8" class="data row0 col8" >0.903806</td>
#       <td id="T_3202d_row0_col9" class="data row0 col9" >0.950687</td>
#       <td id="T_3202d_row0_col10" class="data row0 col10" >-0.361739</td>
#       <td id="T_3202d_row0_col11" class="data row0 col11" >1.909948</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# #T_6b2ec_row0_col0, #T_6b2ec_row0_col1, #T_6b2ec_row0_col2, #T_6b2ec_row0_col3, #T_6b2ec_row0_col4, #T_6b2ec_row0_col5, #T_6b2ec_row0_col6, #T_6b2ec_row0_col7, #T_6b2ec_row0_col8, #T_6b2ec_row0_col9, #T_6b2ec_row0_col10, #T_6b2ec_row0_col11 {
#   text-align: right;
# }
# </style>
# <table id="T_6b2ec_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Null</th>
#       <th class="col_heading level0 col1" >Not Null</th>
#       <th class="col_heading level0 col2" >Min</th>
#       <th class="col_heading level0 col3" >Q1</th>
#       <th class="col_heading level0 col4" >Med</th>
#       <th class="col_heading level0 col5" >Mean</th>
#       <th class="col_heading level0 col6" >Q3</th>
#       <th class="col_heading level0 col7" >Max</th>
#       <th class="col_heading level0 col8" >Var</th>
#       <th class="col_heading level0 col9" >Std</th>
#       <th class="col_heading level0 col10" >Skew</th>
#       <th class="col_heading level0 col11" >Kurt</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_6b2ec_level0_row0" class="row_heading level0 row0" >EXT_SOURCE_2</th>
#       <td id="T_6b2ec_row0_col0" class="data row0 col0" >0</td>
#       <td id="T_6b2ec_row0_col1" class="data row0 col1" >197880</td>
#       <td id="T_6b2ec_row0_col2" class="data row0 col2" >-2.695291</td>
#       <td id="T_6b2ec_row0_col3" class="data row0 col3" >-1.030458</td>
#       <td id="T_6b2ec_row0_col4" class="data row0 col4" >-0.047662</td>
#       <td id="T_6b2ec_row0_col5" class="data row0 col5" >-0.254113</td>
#       <td id="T_6b2ec_row0_col6" class="data row0 col6" >0.586596</td>
#       <td id="T_6b2ec_row0_col7" class="data row0 col7" >1.783975</td>
#       <td id="T_6b2ec_row0_col8" class="data row0 col8" >1.061856</td>
#       <td id="T_6b2ec_row0_col9" class="data row0 col9" >1.030464</td>
#       <td id="T_6b2ec_row0_col10" class="data row0 col10" >-0.488499</td>
#       <td id="T_6b2ec_row0_col11" class="data row0 col11" >-0.768289</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# #T_b456d_row0_col0, #T_b456d_row0_col1, #T_b456d_row0_col2, #T_b456d_row0_col3, #T_b456d_row0_col4, #T_b456d_row0_col5, #T_b456d_row0_col6, #T_b456d_row0_col7, #T_b456d_row0_col8, #T_b456d_row0_col9, #T_b456d_row0_col10, #T_b456d_row0_col11 {
#   text-align: right;
# }
# </style>
# <table id="T_b456d_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Null</th>
#       <th class="col_heading level0 col1" >Not Null</th>
#       <th class="col_heading level0 col2" >Min</th>
#       <th class="col_heading level0 col3" >Q1</th>
#       <th class="col_heading level0 col4" >Med</th>
#       <th class="col_heading level0 col5" >Mean</th>
#       <th class="col_heading level0 col6" >Q3</th>
#       <th class="col_heading level0 col7" >Max</th>
#       <th class="col_heading level0 col8" >Var</th>
#       <th class="col_heading level0 col9" >Std</th>
#       <th class="col_heading level0 col10" >Skew</th>
#       <th class="col_heading level0 col11" >Kurt</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_b456d_level0_row0" class="row_heading level0 row0" >EXT_SOURCE_3</th>
#       <td id="T_b456d_row0_col0" class="data row0 col0" >0</td>
#       <td id="T_b456d_row0_col1" class="data row0 col1" >197880</td>
#       <td id="T_b456d_row0_col2" class="data row0 col2" >-2.949046</td>
#       <td id="T_b456d_row0_col3" class="data row0 col3" >-0.882604</td>
#       <td id="T_b456d_row0_col4" class="data row0 col4" >0.090955</td>
#       <td id="T_b456d_row0_col5" class="data row0 col5" >-0.218663</td>
#       <td id="T_b456d_row0_col6" class="data row0 col6" >0.366301</td>
#       <td id="T_b456d_row0_col7" class="data row0 col7" >2.177076</td>
#       <td id="T_b456d_row0_col8" class="data row0 col8" >1.004385</td>
#       <td id="T_b456d_row0_col9" class="data row0 col9" >1.002190</td>
#       <td id="T_b456d_row0_col10" class="data row0 col10" >-0.397066</td>
#       <td id="T_b456d_row0_col11" class="data row0 col11" >-0.304086</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# #T_82f3a_row0_col0, #T_82f3a_row0_col1, #T_82f3a_row0_col2, #T_82f3a_row0_col3, #T_82f3a_row0_col4, #T_82f3a_row0_col5, #T_82f3a_row0_col6, #T_82f3a_row0_col7, #T_82f3a_row0_col8, #T_82f3a_row0_col9, #T_82f3a_row0_col10, #T_82f3a_row0_col11 {
#   text-align: right;
# }
# </style>
# <table id="T_82f3a_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Null</th>
#       <th class="col_heading level0 col1" >Not Null</th>
#       <th class="col_heading level0 col2" >Min</th>
#       <th class="col_heading level0 col3" >Q1</th>
#       <th class="col_heading level0 col4" >Med</th>
#       <th class="col_heading level0 col5" >Mean</th>
#       <th class="col_heading level0 col6" >Q3</th>
#       <th class="col_heading level0 col7" >Max</th>
#       <th class="col_heading level0 col8" >Var</th>
#       <th class="col_heading level0 col9" >Std</th>
#       <th class="col_heading level0 col10" >Skew</th>
#       <th class="col_heading level0 col11" >Kurt</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_82f3a_level0_row0" class="row_heading level0 row0" >CODE_GENDER</th>
#       <td id="T_82f3a_row0_col0" class="data row0 col0" >0</td>
#       <td id="T_82f3a_row0_col1" class="data row0 col1" >197880</td>
#       <td id="T_82f3a_row0_col2" class="data row0 col2" >-0.721054</td>
#       <td id="T_82f3a_row0_col3" class="data row0 col3" >-0.721054</td>
#       <td id="T_82f3a_row0_col4" class="data row0 col4" >-0.721054</td>
#       <td id="T_82f3a_row0_col5" class="data row0 col5" >0.081058</td>
#       <td id="T_82f3a_row0_col6" class="data row0 col6" >1.386744</td>
#       <td id="T_82f3a_row0_col7" class="data row0 col7" >3.494542</td>
#       <td id="T_82f3a_row0_col8" class="data row0 col8" >0.961550</td>
#       <td id="T_82f3a_row0_col9" class="data row0 col9" >0.980587</td>
#       <td id="T_82f3a_row0_col10" class="data row0 col10" >0.490463</td>
#       <td id="T_82f3a_row0_col11" class="data row0 col11" >-1.684960</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# #T_adf0f_row0_col0, #T_adf0f_row0_col1, #T_adf0f_row0_col2, #T_adf0f_row0_col3, #T_adf0f_row0_col4, #T_adf0f_row0_col5, #T_adf0f_row0_col6, #T_adf0f_row0_col7, #T_adf0f_row0_col8, #T_adf0f_row0_col9, #T_adf0f_row0_col10, #T_adf0f_row0_col11 {
#   text-align: right;
# }
# </style>
# <table id="T_adf0f_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Null</th>
#       <th class="col_heading level0 col1" >Not Null</th>
#       <th class="col_heading level0 col2" >Min</th>
#       <th class="col_heading level0 col3" >Q1</th>
#       <th class="col_heading level0 col4" >Med</th>
#       <th class="col_heading level0 col5" >Mean</th>
#       <th class="col_heading level0 col6" >Q3</th>
#       <th class="col_heading level0 col7" >Max</th>
#       <th class="col_heading level0 col8" >Var</th>
#       <th class="col_heading level0 col9" >Std</th>
#       <th class="col_heading level0 col10" >Skew</th>
#       <th class="col_heading level0 col11" >Kurt</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_adf0f_level0_row0" class="row_heading level0 row0" >NAME_FAMILY_STATUS</th>
#       <td id="T_adf0f_row0_col0" class="data row0 col0" >0</td>
#       <td id="T_adf0f_row0_col1" class="data row0 col1" >197880</td>
#       <td id="T_adf0f_row0_col2" class="data row0 col2" >-1.259823</td>
#       <td id="T_adf0f_row0_col3" class="data row0 col3" >-0.404299</td>
#       <td id="T_adf0f_row0_col4" class="data row0 col4" >-0.404299</td>
#       <td id="T_adf0f_row0_col5" class="data row0 col5" >-0.016847</td>
#       <td id="T_adf0f_row0_col6" class="data row0 col6" >0.451225</td>
#       <td id="T_adf0f_row0_col7" class="data row0 col7" >3.017798</td>
#       <td id="T_adf0f_row0_col8" class="data row0 col8" >0.876691</td>
#       <td id="T_adf0f_row0_col9" class="data row0 col9" >0.936318</td>
#       <td id="T_adf0f_row0_col10" class="data row0 col10" >1.509928</td>
#       <td id="T_adf0f_row0_col11" class="data row0 col11" >2.182694</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# #T_c5329_row0_col0, #T_c5329_row0_col1, #T_c5329_row0_col2, #T_c5329_row0_col3, #T_c5329_row0_col4, #T_c5329_row0_col5, #T_c5329_row0_col6, #T_c5329_row0_col7, #T_c5329_row0_col8, #T_c5329_row0_col9, #T_c5329_row0_col10, #T_c5329_row0_col11 {
#   text-align: right;
# }
# </style>
# <table id="T_c5329_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Null</th>
#       <th class="col_heading level0 col1" >Not Null</th>
#       <th class="col_heading level0 col2" >Min</th>
#       <th class="col_heading level0 col3" >Q1</th>
#       <th class="col_heading level0 col4" >Med</th>
#       <th class="col_heading level0 col5" >Mean</th>
#       <th class="col_heading level0 col6" >Q3</th>
#       <th class="col_heading level0 col7" >Max</th>
#       <th class="col_heading level0 col8" >Var</th>
#       <th class="col_heading level0 col9" >Std</th>
#       <th class="col_heading level0 col10" >Skew</th>
#       <th class="col_heading level0 col11" >Kurt</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_c5329_level0_row0" class="row_heading level0 row0" >AMT_REQ_CREDIT_BUREAU_TOTAL</th>
#       <td id="T_c5329_row0_col0" class="data row0 col0" >0</td>
#       <td id="T_c5329_row0_col1" class="data row0 col1" >197880</td>
#       <td id="T_c5329_row0_col2" class="data row0 col2" >-0.955329</td>
#       <td id="T_c5329_row0_col3" class="data row0 col3" >-0.955329</td>
#       <td id="T_c5329_row0_col4" class="data row0 col4" >-0.242536</td>
#       <td id="T_c5329_row0_col5" class="data row0 col5" >-0.041949</td>
#       <td id="T_c5329_row0_col6" class="data row0 col6" >0.383324</td>
#       <td id="T_c5329_row0_col7" class="data row0 col7" >12.431208</td>
#       <td id="T_c5329_row0_col8" class="data row0 col8" >0.899815</td>
#       <td id="T_c5329_row0_col9" class="data row0 col9" >0.948586</td>
#       <td id="T_c5329_row0_col10" class="data row0 col10" >1.450475</td>
#       <td id="T_c5329_row0_col11" class="data row0 col11" >3.430654</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# #T_6300a_row0_col0, #T_6300a_row0_col1, #T_6300a_row0_col2, #T_6300a_row0_col3, #T_6300a_row0_col4, #T_6300a_row0_col5, #T_6300a_row0_col6, #T_6300a_row0_col7, #T_6300a_row0_col8, #T_6300a_row0_col9, #T_6300a_row0_col10, #T_6300a_row0_col11 {
#   text-align: right;
# }
# </style>
# <table id="T_6300a_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Null</th>
#       <th class="col_heading level0 col1" >Not Null</th>
#       <th class="col_heading level0 col2" >Min</th>
#       <th class="col_heading level0 col3" >Q1</th>
#       <th class="col_heading level0 col4" >Med</th>
#       <th class="col_heading level0 col5" >Mean</th>
#       <th class="col_heading level0 col6" >Q3</th>
#       <th class="col_heading level0 col7" >Max</th>
#       <th class="col_heading level0 col8" >Var</th>
#       <th class="col_heading level0 col9" >Std</th>
#       <th class="col_heading level0 col10" >Skew</th>
#       <th class="col_heading level0 col11" >Kurt</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_6300a_level0_row0" class="row_heading level0 row0" >BIRTH_EMPLOYED_INTERVEL</th>
#       <td id="T_6300a_row0_col0" class="data row0 col0" >0</td>
#       <td id="T_6300a_row0_col1" class="data row0 col1" >197880</td>
#       <td id="T_6300a_row0_col2" class="data row0 col2" >-0.509004</td>
#       <td id="T_6300a_row0_col3" class="data row0 col3" >-0.485260</td>
#       <td id="T_6300a_row0_col4" class="data row0 col4" >-0.465764</td>
#       <td id="T_6300a_row0_col5" class="data row0 col5" >-0.073792</td>
#       <td id="T_6300a_row0_col6" class="data row0 col6" >-0.437684</td>
#       <td id="T_6300a_row0_col7" class="data row0 col7" >2.157068</td>
#       <td id="T_6300a_row0_col8" class="data row0 col8" >0.860591</td>
#       <td id="T_6300a_row0_col9" class="data row0 col9" >0.927681</td>
#       <td id="T_6300a_row0_col10" class="data row0 col10" >1.936384</td>
#       <td id="T_6300a_row0_col11" class="data row0 col11" >1.776821</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# #T_25712_row0_col0, #T_25712_row0_col1, #T_25712_row0_col2, #T_25712_row0_col3, #T_25712_row0_col4, #T_25712_row0_col5, #T_25712_row0_col6, #T_25712_row0_col7, #T_25712_row0_col8, #T_25712_row0_col9, #T_25712_row0_col10, #T_25712_row0_col11 {
#   text-align: right;
# }
# </style>
# <table id="T_25712_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Null</th>
#       <th class="col_heading level0 col1" >Not Null</th>
#       <th class="col_heading level0 col2" >Min</th>
#       <th class="col_heading level0 col3" >Q1</th>
#       <th class="col_heading level0 col4" >Med</th>
#       <th class="col_heading level0 col5" >Mean</th>
#       <th class="col_heading level0 col6" >Q3</th>
#       <th class="col_heading level0 col7" >Max</th>
#       <th class="col_heading level0 col8" >Var</th>
#       <th class="col_heading level0 col9" >Std</th>
#       <th class="col_heading level0 col10" >Skew</th>
#       <th class="col_heading level0 col11" >Kurt</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_25712_level0_row0" class="row_heading level0 row0" >AMT_INCOME_TOTAL</th>
#       <td id="T_25712_row0_col0" class="data row0 col0" >0</td>
#       <td id="T_25712_row0_col1" class="data row0 col1" >197880</td>
#       <td id="T_25712_row0_col2" class="data row0 col2" >-0.523016</td>
#       <td id="T_25712_row0_col3" class="data row0 col3" >-0.206328</td>
#       <td id="T_25712_row0_col4" class="data row0 col4" >-0.099671</td>
#       <td id="T_25712_row0_col5" class="data row0 col5" >-0.016667</td>
#       <td id="T_25712_row0_col6" class="data row0 col6" >0.093442</td>
#       <td id="T_25712_row0_col7" class="data row0 col7" >426.009909</td>
#       <td id="T_25712_row0_col8" class="data row0 col8" >3.363961</td>
#       <td id="T_25712_row0_col9" class="data row0 col9" >1.834110</td>
#       <td id="T_25712_row0_col10" class="data row0 col10" >177.454193</td>
#       <td id="T_25712_row0_col11" class="data row0 col11" >34444.007015</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# #T_bc431_row0_col0, #T_bc431_row0_col1, #T_bc431_row0_col2, #T_bc431_row0_col3, #T_bc431_row0_col4, #T_bc431_row0_col5, #T_bc431_row0_col6, #T_bc431_row0_col7, #T_bc431_row0_col8, #T_bc431_row0_col9, #T_bc431_row0_col10, #T_bc431_row0_col11 {
#   text-align: right;
# }
# </style>
# <table id="T_bc431_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Null</th>
#       <th class="col_heading level0 col1" >Not Null</th>
#       <th class="col_heading level0 col2" >Min</th>
#       <th class="col_heading level0 col3" >Q1</th>
#       <th class="col_heading level0 col4" >Med</th>
#       <th class="col_heading level0 col5" >Mean</th>
#       <th class="col_heading level0 col6" >Q3</th>
#       <th class="col_heading level0 col7" >Max</th>
#       <th class="col_heading level0 col8" >Var</th>
#       <th class="col_heading level0 col9" >Std</th>
#       <th class="col_heading level0 col10" >Skew</th>
#       <th class="col_heading level0 col11" >Kurt</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_bc431_level0_row0" class="row_heading level0 row0" >AMT_GOODS_PRICE</th>
#       <td id="T_bc431_row0_col0" class="data row0 col0" >0</td>
#       <td id="T_bc431_row0_col1" class="data row0 col1" >197880</td>
#       <td id="T_bc431_row0_col2" class="data row0 col2" >-1.336283</td>
#       <td id="T_bc431_row0_col3" class="data row0 col3" >-0.776050</td>
#       <td id="T_bc431_row0_col4" class="data row0 col4" >-0.240174</td>
#       <td id="T_bc431_row0_col5" class="data row0 col5" >-0.081492</td>
#       <td id="T_bc431_row0_col6" class="data row0 col6" >0.368775</td>
#       <td id="T_bc431_row0_col7" class="data row0 col7" >9.503013</td>
#       <td id="T_bc431_row0_col8" class="data row0 col8" >0.793708</td>
#       <td id="T_bc431_row0_col9" class="data row0 col9" >0.890903</td>
#       <td id="T_bc431_row0_col10" class="data row0 col10" >1.492657</td>
#       <td id="T_bc431_row0_col11" class="data row0 col11" >3.291327</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# #T_eff52_row0_col0, #T_eff52_row0_col1, #T_eff52_row0_col2, #T_eff52_row0_col3, #T_eff52_row0_col4, #T_eff52_row0_col5, #T_eff52_row0_col6, #T_eff52_row0_col7, #T_eff52_row0_col8, #T_eff52_row0_col9, #T_eff52_row0_col10, #T_eff52_row0_col11 {
#   text-align: right;
# }
# </style>
# <table id="T_eff52_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Null</th>
#       <th class="col_heading level0 col1" >Not Null</th>
#       <th class="col_heading level0 col2" >Min</th>
#       <th class="col_heading level0 col3" >Q1</th>
#       <th class="col_heading level0 col4" >Med</th>
#       <th class="col_heading level0 col5" >Mean</th>
#       <th class="col_heading level0 col6" >Q3</th>
#       <th class="col_heading level0 col7" >Max</th>
#       <th class="col_heading level0 col8" >Var</th>
#       <th class="col_heading level0 col9" >Std</th>
#       <th class="col_heading level0 col10" >Skew</th>
#       <th class="col_heading level0 col11" >Kurt</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_eff52_level0_row0" class="row_heading level0 row0" >AMT_CREDIT_SUM_DEBT</th>
#       <td id="T_eff52_row0_col0" class="data row0 col0" >0</td>
#       <td id="T_eff52_row0_col1" class="data row0 col1" >197880</td>
#       <td id="T_eff52_row0_col2" class="data row0 col2" >-2.533409</td>
#       <td id="T_eff52_row0_col3" class="data row0 col3" >-0.248870</td>
#       <td id="T_eff52_row0_col4" class="data row0 col4" >-0.200464</td>
#       <td id="T_eff52_row0_col5" class="data row0 col5" >-0.020081</td>
#       <td id="T_eff52_row0_col6" class="data row0 col6" >-0.041433</td>
#       <td id="T_eff52_row0_col7" class="data row0 col7" >72.331396</td>
#       <td id="T_eff52_row0_col8" class="data row0 col8" >0.687123</td>
#       <td id="T_eff52_row0_col9" class="data row0 col9" >0.828929</td>
#       <td id="T_eff52_row0_col10" class="data row0 col10" >23.732182</td>
#       <td id="T_eff52_row0_col11" class="data row0 col11" >1210.817828</td>
#     </tr>
#   </tbody>
# </table>
#                              Null  Not Null       Min        Q1       Med  \
# EXT_SOURCE_1                    0    197880 -3.506565 -0.221864  0.013770
# EXT_SOURCE_2                    0    197880 -2.695291 -1.030458 -0.047662
# EXT_SOURCE_3                    0    197880 -2.949046 -0.882604  0.090955
# CODE_GENDER                     0    197880 -0.721054 -0.721054 -0.721054
# NAME_FAMILY_STATUS              0    197880 -1.259823 -0.404299 -0.404299
# AMT_REQ_CREDIT_BUREAU_TOTAL     0    197880 -0.955329 -0.955329 -0.242536
# BIRTH_EMPLOYED_INTERVEL         0    197880 -0.509004 -0.485260 -0.465764
# AMT_INCOME_TOTAL                0    197880 -0.523016 -0.206328 -0.099671
# AMT_GOODS_PRICE                 0    197880 -1.336283 -0.776050 -0.240174
# AMT_CREDIT_SUM_DEBT             0    197880 -2.533409 -0.248870 -0.200464
#
#                                  Mean        Q3         Max       Var  \
# EXT_SOURCE_1                -0.140326  0.013770    3.206794  0.903806
# EXT_SOURCE_2                -0.254113  0.586596    1.783975  1.061856
# EXT_SOURCE_3                -0.218663  0.366301    2.177076  1.004385
# CODE_GENDER                  0.081058  1.386744    3.494542  0.961550
# NAME_FAMILY_STATUS          -0.016847  0.451225    3.017798  0.876691
# AMT_REQ_CREDIT_BUREAU_TOTAL -0.041949  0.383324   12.431208  0.899815
# BIRTH_EMPLOYED_INTERVEL     -0.073792 -0.437684    2.157068  0.860591
# AMT_INCOME_TOTAL            -0.016667  0.093442  426.009909  3.363961
# AMT_GOODS_PRICE             -0.081492  0.368775    9.503013  0.793708
# AMT_CREDIT_SUM_DEBT         -0.020081 -0.041433   72.331396  0.687123
#
#                                   Std        Skew          Kurt
# EXT_SOURCE_1                 0.950687   -0.361739      1.909948
# EXT_SOURCE_2                 1.030464   -0.488499     -0.768289
# EXT_SOURCE_3                 1.002190   -0.397066     -0.304086
# CODE_GENDER                  0.980587    0.490463     -1.684960
# NAME_FAMILY_STATUS           0.936318    1.509928      2.182694
# AMT_REQ_CREDIT_BUREAU_TOTAL  0.948586    1.450475      3.430654
# BIRTH_EMPLOYED_INTERVEL      0.927681    1.936384      1.776821
# AMT_INCOME_TOTAL             1.834110  177.454193  34444.007015
# AMT_GOODS_PRICE              0.890903    1.492657      3.291327
# AMT_CREDIT_SUM_DEBT          0.828929   23.732182   1210.817828

# %%
main_features_pd.round(2).to_pickle("main_features_pd.pickle")

# %%
main_features_pd.index[0]
# Out:
# 'EXT_SOURCE_1'

# %%
main_features_pd = main_features_pd.round(2)

# %%
main_features_pd.loc[main_features[1],"Min"]
# Out:
# -2.7

# %%
with open('model_opti.pickle', 'wb') as f:
    pickle.dump(model_opti, f)

# %%
with open('shap_values_tree.pickle', 'wb') as f:
    pickle.dump(shap_values_tree, f)

# %%
with open('X_test2_sc.pickle', 'wb') as f:
    pickle.dump(X_test2_sc, f)

# %%
model_opti.predict(X_test2_sc[1].reshape(1,-1))
# Out:
# array([0.])

# %%
{"proba_0" : model_opti.predict_proba([X_train2_sc_pd_mean])[0][0]}
# Out:
# {'proba_0': 0.0028108824950806577}

# %%
{"proba_0" : model_opti.predict_proba(X_test2_sc[1].reshape(1,-1))[0][0]}
# Out:
# {'proba_0': 0.739038510073049}

# %%
# categorical_encoder = Pipeline([("imputer", SimpleImputer(strategy="most_frequent")), ("label_encoder" , LabelEncoder())])
# numerical_pipe = SimpleImputer(strategy="median")

# preprocessing = ColumnTransformer(
#     [
#         ("categorical", categorical_encoder, cat_list ),
#         ("continuous", numerical_pipe, num_list),
#         ("discrete", SimpleImputer(strategy="most_frequent"), dis_num_list)
#     ]
# )

# pipeline = Pipeline(
#     [
#         ("preprocess", preprocessing),
#         ("scaler", StandardScaler()),
#         ("OSUS", osus),
#         ("classifier", LogisticRegression()),
#     ]
# )
